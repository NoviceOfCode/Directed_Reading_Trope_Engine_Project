# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import ast
import networkx as nx
import plotly.graph_objs as go
from plotly.subplots import make_subplots
import plotly.express as px

# %% [markdown]
# # General Functions

# %% [markdown]
# # Finding Cosine Simularity Name and Description of Trope

# %%
df = pd.read_csv('../data_clean/embeddings.csv')

# %%
df.head()
# Out:
#                                          d_embedding  \
# 0  [0.06963171064853668, 0.0030629639513790607, -...
# 1  [0.015573586337268353, 0.0399489663541317, 0.0...
# 2  [0.03458022698760033, 0.0070857820101082325, 0...
# 3  [0.09302520006895065, -0.030586645007133484, -...
# 4  [0.04039151221513748, 0.09288910031318665, 0.0...
#
#                                          n_embedding             trope_name
# 0  [0.05705825984477997, -0.043769609183073044, 0...        Aardvark Trunks
# 1  [0.009882059879601002, 0.03227100521326065, -0...         Abandoned Area
# 2  [0.013515202328562737, -0.00612090528011322, -...   Abandoned Camp Ruins
# 3  [0.06870320439338684, 0.04672708734869957, 0.0...  Abandoned Catchphrase
# 4  [0.012362676672637463, 0.058168645948171616, 0...     Abandoned Hospital

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29903 entries, 0 to 29902
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   d_embedding  29903 non-null  object
#  1   n_embedding  29903 non-null  object
#  2   trope_name   29903 non-null  object
# dtypes: object(3)
# memory usage: 701.0+ KB

# %%
df['d_embedding'][0]
# Out:
# '[0.06963171064853668, 0.0030629639513790607, -0.008121015504002571, -0.013888058252632618, -0.01011512242257595, 0.014636923559010029, -0.01193075068295002, 0.029771361500024796, -0.01081668771803379, -0.06676766276359558, -0.010310154408216476, -0.02241273783147335, 0.05320066586136818, 0.024889009073376656, 0.03181518614292145, -0.08361653238534927, -0.0028990868013352156, 0.028244387358427048, -0.012618741020560265, -0.007032736670225859, -0.012423649430274963, 0.017461754381656647, 0.00025233018095605075, 0.047600358724594116, -0.010778825730085373, -0.03426583856344223, 0.02366022951900959, -0.035148538649082184, 0.0285659097135067, -0.020996391773223877, 0.03030324913561344, -0.030726205557584763, -0.002634217729791999, 0.02133430354297161, 2.1636437850247603e-06, -0.013711065985262394, 0.0159982331097126, 0.0012827098835259676, -0.0006692968308925629, -0.004904448986053467, 0.06002402305603027, -0.028040504083037376, 0.04168557748198509, -0.05156862735748291, 0.03662789985537529, -0.04549340158700943, 0.09087150543928146, -0.021930525079369545, 0.014215420000255108, 0.0073171379044651985, 0.020718714222311974, -0.07953893393278122, -0.02034629136323929, -0.010347715578973293, 0.035357002168893814, 0.059066276997327805, -0.007140503730624914, -0.05926137417554855, -0.01796090230345726, 0.010314368642866611, -0.01917475089430809, -0.016189100220799446, 0.005534165073186159, 0.01815047860145569, 0.050151702016592026, 0.043908391147851944, 0.024968553334474564, -0.06090487167239189, 0.05043795704841614, 0.02182135544717312, -0.010197808966040611, -0.02245837077498436, -0.023226840421557426, 0.017756501212716103, -0.028340600430965424, 0.04370659589767456, 0.0084600280970335, 0.04599960893392563, -0.011338653974235058, 0.014314468018710613, -0.004791193641722202, 0.0005234619602560997, -0.03030426613986492, 0.03690647706389427, -0.0325913242995739, -0.049061402678489685, 0.02974371425807476, 0.008142399601638317, -0.019027207046747208, -0.03616964817047119, -0.01682610996067524, -0.017307370901107788, 0.04294360429048538, 0.05531609430909157, -0.026522502303123474, 0.015462329611182213, -0.03618434816598892, -0.0660218596458435, 0.04607513174414635, -0.007513068616390228, 0.02026948146522045, -0.004348300863057375, -0.08699135482311249, 0.04487347975373268, 0.004321677144616842, -0.00960763543844223, 0.018164964392781258, 0.025401879101991653, -0.009778953157365322, 0.00985519215464592, 0.0062173157930374146, -0.047392625361680984, 0.0018550459062680602, 0.04336944594979286, 0.00234966934658587, -0.031885258853435516, 0.023594358935952187, -0.033874742686748505, -0.0006661576917394996, -0.00436240853741765, -0.019376063719391823, 0.03606891632080078, -0.035910118371248245, -0.012231535278260708, -0.03851093724370003, -0.02626768872141838, -0.04482119157910347, 0.06950581818819046, 0.014864232391119003, -0.0054476214572787285, 0.007048794999718666, -0.015380362048745155, -0.02778380922973156, -0.036436982452869415, -0.009127943776547909, 0.038764555007219315, 0.04393992945551872, -0.00845416635274887, 0.04290219023823738, 0.0027612135745584965, 0.005723285023123026, -0.049612194299697876, -0.059721704572439194, 0.015806330367922783, 0.049007806926965714, -0.03136233612895012, 0.01723410189151764, 0.04567680135369301, -0.009825216606259346, 0.026869263499975204, 0.008217877708375454, 0.06363192200660706, -0.03239014744758606, 0.020874181762337685, 0.02113497443497181, 0.0349755622446537, 0.010446827858686447, -0.025546841323375702, -0.015155402012169361, 0.05044487491250038, -0.008886388503015041, -0.03429734706878662, -0.02314508520066738, -0.04052349179983139, -0.025060608983039856, -0.02892712503671646, 0.025863967835903168, 0.011042301543056965, 0.02650701068341732, 0.03990931436419487, 0.045452021062374115, 0.03403594717383385, -0.038451071828603745, -0.07178236544132233, 0.011736959218978882, 0.07369375228881836, -0.005881158635020256, 0.03561236709356308, 0.05913184583187103, -0.017649294808506966, 0.027319924905896187 ...

# %%
# Making sure values are in expected shape
df['d_embedding'] = df['d_embedding'].apply(ast.literal_eval)
df['n_embedding'] = df['n_embedding'].apply(ast.literal_eval)

# %%
df['cosine_similarity'] = df.apply(
    lambda x: cosine_similarity(
        np.array(x['d_embedding']).reshape(1, -1),
        np.array(x['n_embedding']).reshape(1, -1)
    )[0][0],  # Extract the cosine similarity value
    axis=1
)

# %% [markdown]
# ## Evaluating

# %%
df.head()

# %%
average = df['cosine_similarity'].mean()
print(f"The average cosine similarity is: {average}")

# %%
high_cosine_similarity = df[df['cosine_similarity'] > 0.5]
high_cosine_similarity.info()

# %%
percent_of_high_cosine_similarity = (high_cosine_similarity.shape[0] / df.shape[0]) * 100
print(f"The percentage of high cosine similarity is: {percent_of_high_cosine_similarity}%")

# %%
neagtive_cosine_similarity = df[df['cosine_similarity'] < 0]
neagtive_cosine_similarity.info()

# %% [markdown]
# ## Graph Creation

# %%
df_sorted = df.sort_values(by='cosine_similarity', ascending=False)

# Creating a colored scatter plot
fig = px.scatter(
    df_sorted,
    x='trope_name',
    y='cosine_similarity',
    color='cosine_similarity',
    labels={'x': 'Trope', 'y': 'Cosine Similarity'},
    title='Cosine Similarity between Trope Names and Descriptions',
    color_continuous_scale='Viridis'
)

fig.update_layout(
    xaxis_title="Trope",
    yaxis_title="Cosine Similarity",
    yaxis=dict(range=[0, 1])
)

fig.show()

# %% [markdown]
# # Finding Cosine Simularity Name and Description of All Other Tropes
# Each name has cosine simluarity done for every embedding of description in the dataset

# %%
df = pd.read_csv('embeddings.csv')

# %%
df['cosine_similarity'] = df['n_embedding'].apply(ast.literal_eval)
df['cosine_similarity'] = df['d_embedding'].apply(ast.literal_eval)

# %%
df['n_embedding'] = df['n_embedding'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
df['d_embedding'] = df['d_embedding'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# %%
d_embedding_matrix = np.vstack(df['d_embedding'].values)
print(d_embedding_matrix.shape)
print(d_embedding_matrix)

# %%
def compute_cosine_similarity(n_embedding):

    n_embedding = np.array(n_embedding)
    # Reshape n_embedding for the function input
    n_embedding_reshaped = n_embedding.reshape(1, -1)
    # Compute cosine similarities
    cos_similarities = cosine_similarity(n_embedding_reshaped, d_embedding_matrix)
    return cos_similarities.flatten()

# %%
df['cosine_similarity'] = df['n_embedding'].apply(compute_cosine_similarity)

# %% [markdown]
# ## Evaluating Results

# %%
df['average_cosine_similarity'] = df['cosine_similarity'].apply(lambda x: sum(x) / len(x))

# %%
df.head()

# %% [markdown]
# ## Graph Visualization

# %% [markdown]
# ## Finding Cosine Simularity Name and Other Names

# %%
df = pd.read_csv('embeddings.csv')

# %%
df['cosine_similarity'] = df['n_embedding'].apply(ast.literal_eval)
df['cosine_similarity'] = df['d_embedding'].apply(ast.literal_eval)

# %%
df['n_embedding'] = df['n_embedding'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
df['d_embedding'] = df['d_embedding'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# %%
n_embedding_matrix = np.vstack(df['n_embedding'].values)
print(d_embedding_matrix.shape)
print(d_embedding_matrix)

# %%
def compute_cosine_similarity(n_embedding, matrix):

    n_embedding = np.array(n_embedding)
    # Reshape n_embedding for the function input
    n_embedding_reshaped = n_embedding.reshape(1, -1)
    # Compute cosine similarities
    cos_similarities = cosine_similarity(n_embedding_reshaped, matrix)
    return cos_similarities.flatten()

# %%
df['cosine_similarity'] = df['n_embedding'].apply(lambda x: compute_cosine_similarity(x, n_embedding_matrix))

# %%
df.head()

# %%
df['average_cosine_similarity'] = df['cosine_similarity'].apply(lambda x: sum(x) / len(x))

# %%
df.head()
