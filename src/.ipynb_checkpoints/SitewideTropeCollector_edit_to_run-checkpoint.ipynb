# %%
import requests
import string
from bs4 import BeautifulSoup
import pandas as pd
from bs4.element import ResultSet
import os

# %% [markdown]
# # Functions

# %%
def track_tropes_crawled(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    td_tags = soup.find_all('td')
    trope_names = []
    trope_links = []
    for td in td_tags:
        a_tag = td.find('a', href=True)
        if a_tag:
            link = a_tag['href']
            trope_links.append(link)
            link_text = a_tag.get_text(strip=True)
            trope_names.append(link_text)
    return pd.DataFrame({'trope_name':trope_names, 'trope_link':trope_links})

# %%
def parsing_trope_page(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the main content div with the id 'main-content'
    main_content = soup.find('div', id='main-content')
    if not main_content:
        print("No 'main-content' found.")
        return None, None, None
    # Find the article with id 'main-entry'
    main_entry = main_content.find('article', id='main-entry')

    if not main_entry:
        print("No 'main-entry' found.")
        return None, None, None

    # Initialize a list to store paragraphs
    paragraphs = []
    related_links = []
    related_link_names = []
    example_descriptions = []
    example_related_links = []
    example_related_link_names = []
    found_examples = False

    # Loop through all elements in the main entry
    for elem in main_entry.find_all(True):
        if elem.name == 'h2':
          break
        if elem.name == 'p':
          paragraph_text = ''
          for content in elem.contents:
              if content.name == 'a' and 'href' in content.attrs:
                  link = content['href']
                  link_text = content.get_text(strip=True)
                  paragraph_text += f' {link_text} '
                  related_links.append(link)
                  related_link_names.append(link_text)
              else:
                    paragraph_text += content.strip() if isinstance(content, str) else ''
          paragraphs.append(paragraph_text.strip())

    for elem in main_entry.find_all(True):
        if elem.name == 'h2':
            if 'Examples' in elem.get_text() or 'Other examples' in elem.get_text():
                found_examples = True
                continue
        if found_examples:
          if 'folder' in elem.get('class',[]):
            list_items = elem.find_all('li')
            for li in list_items:
              example_text = ''
              for content in li.contents:
                if content.name == 'a' and 'href' in content.attrs:
                  link = content['href']
                  link_text = content.get_text(strip=True)
                  example_text += f' {link_text} '
                  example_related_links.append(link)
                  example_related_link_names.append(link_text)
                else:
                  example_text += content.strip() if isinstance(content, str) else ''
                if content.name == 'em':
                  for em_content in content.contents:
                    if em_content.name == 'a' and 'href' in em_content.attrs:
                      link = em_content['href']
                      link_text = em_content.get_text(strip=True)
                      example_text += f' {link_text} '
                      example_related_links.append(link)
                      example_related_link_names.append(link_text)
                    else:
                      example_text += em_content.strip() if isinstance(em_content, str) else ''
              example_descriptions.append(example_text.strip())
    # Print the paragraphs
    if not paragraphs:
        print("No paragraphs found before the 'Examples' section.")

    if not example_descriptions:
        print("No example descriptions found.")
        print(len(example_descriptions))

    return paragraphs, related_links, related_link_names, example_descriptions, example_related_links, example_related_link_names

# %% [markdown]
# # Widespread Ripping

# %%
df_copy = pd.read_csv('all_trope_names_links.csv')

# %%
output_folder = '/content/drive/MyDrive/04 Class Directed Reading/Trope_Comic_Research/data_raw/parsed_tropes.csv'

# %%
def parsing_with_csv_aid(df, output_folder, message):

  if os.path.exists(output_folder):
    output_df = pd.read_csv(output_folder)
    print("Created CSV!")
  else:
    output_df = pd.DataFrame(columns=df.columns)
    print("Found CSV!")
  for index, row in df.iterrows():
    if index in output_df.index:
      print(f"Trope '{row['trope_name']}' already exists, skipping.")
      continue
    try:
      name = row['trope_name']
      url = row['trope_link']
      #example_descriptions, example_related_links, example_related_link_names
      row['trope_description'], row['related_link_names'], row['related_links'],\
       row['example_descriptions'], row['example_related_links'], row['example_related_link_names']= parsing_trope_page(url)

      output_df = pd.concat([output_df, pd.DataFrame([row])])

      output_df.to_csv(output_folder, index=False)
      print(f"Successfully processed and saved: {name}")

    except requests.exceptions.RequestException as e:
          print(f"Failed to process {name} at row {index}: {e}")
          break  # Stop the loop if there is an error

# %%
parsing_with_csv_aid(df_copy, output_folder, "test")
# Out:
# Streaming output truncated to the last 5000 lines.
# Trope 'Absurdly Powerful Student Council' already exists, skipping.
# Trope 'Absurdly Sharp Blade' already exists, skipping.
# Trope 'Absurdly Sharp Claws' already exists, skipping.
# Trope 'Absurdly Short Level' already exists, skipping.
# Trope 'Absurdly Short Production Time' already exists, skipping.
# Trope 'Absurdly Spacious Sewer' already exists, skipping.
# Trope 'Absurdly Youthful Mother' already exists, skipping.
# Trope 'Absurd Phobia' already exists, skipping.
# Trope 'Ab Urbe Condita' already exists, skipping.
# Trope 'Abuse Discretion Shot' already exists, skipping.
# Trope 'Abuse Mistake' already exists, skipping.
# Trope 'Abuse Of Return Policy' already exists, skipping.
# Trope 'Abusive Advertising' already exists, skipping.
# Trope 'Abusive Alien Parents' already exists, skipping.
# Trope 'Abusive Offspring' already exists, skipping.
# Trope 'Abusive Parents' already exists, skipping.
# Trope 'Abusive Precursors' already exists, skipping.
# Trope 'Abusive Workplace' already exists, skipping.
# Trope 'Academia Elitism' already exists, skipping.
# Trope 'Academic Alpha Bitch' already exists, skipping.
# Trope 'Academic Athlete' already exists, skipping.
# Trope 'Academy Of Adventure' already exists, skipping.
# Trope 'Academy Of Evil' already exists, skipping.
# Trope 'A Cappella' already exists, skipping.
# Trope 'A Cat In A Gang Of Dogs' already exists, skipping.
# Trope 'Accent Adaptation' already exists, skipping.
# Trope 'Accent Depundent' already exists, skipping.
# Trope 'Accent Interest' already exists, skipping.
# Trope 'Accent Relapse' already exists, skipping.
# Trope 'Accents Arent Hereditary' already exists, skipping.
# Trope 'Accent Slip Up' already exists, skipping.
# Trope 'Accentuate The Negative' already exists, skipping.
# Trope 'Accent Upon The Wrong Syllable' already exists, skipping.
# Trope 'Acceptable Breaks From Canon' already exists, skipping.
# Trope 'Accessory Wearing Cartoon Animal' already exists, skipping.
# Trope 'Accidental Adultery' already exists, skipping.
# Trope 'Accidental Aesop' already exists, skipping.
# Trope 'Accidental Aiming Skills' already exists, skipping.
# Trope 'Accidental Art' already exists, skipping.
# Trope 'Accidental Astronaut' already exists, skipping.
# Trope 'Accidental Athlete' already exists, skipping.
# Trope 'Accidental Bargaining Skills' already exists, skipping.
# Trope 'Accidental Bid' already exists, skipping.
# Trope 'Accidental Celebrity' already exists, skipping.
# Trope 'Accidental Child Killer Backstory' already exists, skipping.
# Trope 'Accidental Dance Craze' already exists, skipping.
# Trope 'Accidental Declaration Of Love' already exists, skipping.
# Trope 'Accidental Discovery' already exists, skipping.
# Trope 'Accidental Downer Ending' already exists, skipping.
# Trope 'Accidental Good Outcome' already exists, skipping.
# Trope 'Accidental Hand Hold' already exists, skipping.
# Trope 'Accidental Hero' already exists, skipping.
# Trope 'Accidental Hug' already exists, skipping.
# Trope 'Accidental Incantation' already exists, skipping.
# Trope 'Accidental Injury Guilt' already exists, skipping.
# Trope 'Accidental Innuendo' already exists, skipping.
# Trope 'Accidental Kidnapping' already exists, skipping.
# Trope 'Accidental Kiss' already exists, skipping.
# Trope 'Accidentally Broke The Mac Guffin' already exists, skipping.
# Trope 'Accidentally Correct Writing' already exists, skipping.
# Trope 'Accidentally Correct Zoology' already exists, skipping.
# Trope 'Accidentally Real Fake Address' already exists, skipping.
# Trope 'Accidental Marriage' already exists, skipping.
# Trope 'Accidental Misnaming' already exists, skipping.
# Trope 'Accidental Murder' already exists, skipping.
# Trope 'Accidental Nightmare Fuel' already exists, skipping.
# Trope 'Accidental Passenger' already exists, skipping.
# Trope 'Accidental Pervert' already exists, skipping.
# Trope 'Accidental Pornomancer' already exists, skipping.
# Trope 'Accidental Proposal' already exists, skipping.
# Trope 'Accidental Public Confession' already exists, skipping.
# Trope 'Accidental Pun' already exists, skipping.
# Trope 'Accidental Rhyme' already exists, skipping.
# Trope 'Accidental Suicide' already exists, skipping.
# Trope 'Accidental Theft' already exists, skipping.
# Trope 'Accidental Tickle Torture' already exists, skipping.
# Trope 'Accidental Time Travel' already exists, skipping.
# Trope 'Accidental Truth' already exists, skipping.
# Trope 'Accidental Unfortunate Gesture' already exists, skipping.
# Trope 'Accidental Ventriloquism' already exists, skipping.
# Trope 'Accident Not Murder' already exists, skipping.
# Trope 'Acclaimed Flop' already exists, skipping.
# Trope 'Accomplice By Inaction' already exists, skipping.
# Trope 'Accordion Man' already exists, skipping.
# Trope 'Accordion To Most Sailors' already exists, skipping.
# Trope 'Accusation Fic' already exists, skipping.
# Trope 'Accuser Of The Brethren' already exists, skipping.
# Trope 'Accuse The Witness' already exists, skipping.
# Trope 'Ace Custom' already exists, skipping.
# Trope 'Ace Of Spades' already exists, skipping.
# Trope 'Ace Pilot' already exists, skipping.
# Trope 'A Chat With Satan' already exists, skipping.
# Trope 'Achey Scars' already exists, skipping.
# Trope 'Achievement Mockery' already exists, skipping.
# Trope 'Achievements In Ignorance' already exists, skipping.
# Trope 'Achievement System' already exists, skipping.
# Trope 'Achievement Test Of Destiny' already exists, skipping.
# Trope 'A Child Shall Lead Them' already exists, skipping.
# Trope 'Achilles Heel' already exists, skipping.
# Trope 'Achilles In His Tent' already exists, skipping.
# Trope 'Achilles Power Cord' already exists, skipping.
# Trope 'Acid Attack' already exists, skipping.
# Trope 'Acid Pool' already exists, skipping.
# Trope 'Acid Reflux Nightmare' already exists, skipping.
# Trope 'Acid Trip Dimension' already exists, skipping.
# Trope 'Acme Products' already exists, skipping.
# Trope 'A Commander Is You' already exists, skipping.
# Trope 'Acoustic License' already exists, skipping.
# Trope 'Acquaintance Denial' already exists, skipping.
# Trope 'Acquainted In Real Life' already exists, skipping.
# Trope 'Acquainted With Emergency Services' already exists, skipping.
# Trope 'Acquired Error At The Printer' already exists, skipping.
# Trope 'Acquired Poison Immunity' already exists, skipping.
# Trope 'Acquired Situational Narcissism' already exists, skipping.
# Trope 'Acquitted Too Late' already exists, skipping.
# Trope 'A Crack In The Ice' already exists, skipping.
# Trope 'Acrofatic' already exists, skipping.
# Trope 'Acronym And Abbreviation Overload' already exists, skipping.
# Trope 'Acronym Confusion' already exists, skipping.
# Trope 'Acronyms Are Easy As Aybeecee' already exists, skipping.
# Trope 'Acrophobic Bird' already exists, skipping.
# Trope 'Act Break' already exists, skipping.
# Trope 'Acting For Two' already exists, skipping.
# Trope 'Acting In The Dark' already exists, skipping.
# Trope 'Acting Out A Daydream' already exists, skipping.
# Trope 'Acting Unnatural' already exists, skipping.
# Trope 'Acting Your Intellectual Age' already exists, skipping.
# Trope 'Action Bar' already exists, skipping.
# Trope 'Action Based Mission' already exists, skipping.
# Trope 'Action Bomb' already exists, skipping.
# Trope 'Action Commands' already exists, skipping.
# Trope 'Action Dad' already exists, skipping.
# Trope 'Action Dress Rip' already exists, skipping.
# Trope 'Action Duo' already exists, skipping.
# Trope 'Action Fashionista' already exists, skipping.
# Trope 'Action Figure File Card' already exists, skipping.
# Trope 'Action Figure Justification' already exists, skipping.
# Trope 'Action Figure Speech' already exists, skipping.
# Trope 'Action Film Quiet Drama Scene' already exists, skipping.
# Trope 'Action Genre' already exists, skipping.
# Trope 'Action Genre Hero Guy' already exists, skipping.
# Trope 'Action Girl' already exists, skipping.
# Trope 'Action Girlfriend' already exists, skipping.
# Trope 'Action Hero' already exists, skipping.
# Trope 'Action Hero Babysitter' already exists, skipping.
# Trope 'Action Hogging Opening' already exists, skipping.
# Trope 'Action Horror' already exists, skipping.
# Trope 'Action Initiative' already exists, skipping.
# Trope 'Action Insurance Gag' already exists, skipping.
# Trope 'Actionized Adaptation' already exists, skipping.
# Trope 'Actionized Sequel' already exists, skipping.
# Trope 'Action Mom' already exists, skipping.
# Trope 'Action Pet' already exists, skipping.
# Trope 'Action Politician' already exists, skipping.
# Trope 'Action Prologue' already exists, skipping.
# Trope 'Action Survivor' already exists, skipping.
# Trope 'Activation Sequence' already exists, skipping.
# Trope 'Activist Fundamentalist Antics' already exists, skipping.
# Trope 'Act Of True Love' already exists, skipping.
# Trope 'Actor Allusion' already exists, skipping.
# Trope 'Actor Existence Limbo' already exists, skipping.
# Trope 'Actor Inspired Element' already exists, skipping.
# Trope 'Actor Inspired Heroism' already exists, skipping.
# Trope 'Actor Is The Title Character' already exists, skipping.
# Trope 'Actor Leaves Character Dies' already exists, skipping.
# Trope 'Actor Muso Show' already exists, skipping.
# Trope 'Actor Role Confusion' already exists, skipping.
# Trope 'Actor Shared Background' already exists, skipping.
# Trope 'Actor Shipping' already exists, skipping.
# Trope 'Actor Swap' already exists, skipping.
# Trope 'Actually A Doombot' already exists, skipping.
# Trope 'Actually A Good Idea' already exists, skipping.
# Trope 'Actually Four Mooks' already exists, skipping.
# Trope 'Actually I Am Him' already exists, skipping.
# Trope 'Actually Not A Vampire' already exists, skipping.
# Trope 'Actually Pretty Funny' already exists, skipping.
# Trope 'Actually Quite Catchy' already exists, skipping.
# Trope 'Actually Thats My Assistant' already exists, skipping.
# Trope 'Actual Pacifist' already exists, skipping.
# Trope 'Actual Play' already exists, skipping.
# Trope 'A Cup Angst' already exists, skipping.
# Trope 'Adam And Eve Plot' already exists, skipping.
# Trope 'Adam And Or Eve' already exists, skipping.
# Trope 'Adam Smith Hates Your Guts' already exists, skipping.
# Trope 'Adam Westing' already exists, skipping.
# Trope 'Adaptational Abomination' already exists, skipping.
# Trope 'Adaptational Achilles Heel' already exists, skipping.
# Trope 'Adaptational Alternate Ending' already exists, skipping.
# Trope 'Adaptational Angst Downgrade' already exists, skipping.
# Trope 'Adaptational Angst Upgrade' already exists, skipping.
# Trope 'Adaptational Attractiveness' already exists, skipping.
# Trope 'Adaptational Backstory Change' already exists, skipping.
# Trope 'Adaptational Badass' already exists, skipping.
# Trope 'Adaptational Comic Relief' already exists, skipping.
# Trope 'Adaptational Consent' already exists, skipping.
# Trope 'Adaptational Consistency' already exists, skipping.
# Trope 'Adaptational Context Change' already exists, skipping.
# Trope 'Adaptational Curves' already exists, skipping.
# Trope 'Adaptational Diversity' already exists, skipping.
# Trope 'Adaptational Dumbass' already exists, skipping.
# Trope 'Adaptational Early Appearance' already exists, skipping.
# Trope 'Adaptational Explanation' already exists, skipping.
# Trope 'Adaptational Friendship' already exists, skipping.
# Trope 'Adaptational Gender Identity' already exists, skipping.
# Trope 'Adaptational Goal Change' already exists, skipping.
# Trope 'Adaptational Hairstyle Change' already exists, skipping.
# Trope 'Adaptational Heroism' already exists, skipping.
# Trope 'Adaptational Intelligence' already exists, skipping.
# Trope 'Adaptational Jerkass' already exists, skipping.
# Trope 'Adaptational Job Change' already exists, skipping.
# Trope 'Adaptational Karma' already exists, skipping.
# Trope 'Adaptational Late Appearance' already exists, skipping.
# Trope 'Adaptational Location Change' already exists, skipping.
# Trope 'Adaptational Modesty' already exists, skipping.
# Trope 'Adaptational Mundanity' already exists, skipping.
# Trope 'Adaptational Nationality' already exists, skipping.
# Trope 'Adaptational Nice Guy' already exists, skipping.
# Trope 'Adaptational Nonsapience' already exists, skipping.
# Trope 'Adaptational Protagonist' already exists, skipping.
# Trope 'Adaptational Romance Downgrade' already exists, skipping.
# Trope 'Adaptational Secrecy Downgrade' already exists, skipping.
# Trope 'Adaptational Self Defense' already exists, skipping.
# Trope 'Adaptational Seriousness' already exists, skipping.
# Trope 'Adaptational Sexuality' already exists, skipping.
# Trope 'Adaptational Skill' already exists, skipping.
# Trope 'Adaptational Skimpiness' already exists, skipping.
# Trope 'Adaptational Slimness' already exists, skipping.
# Trope 'Adaptational Superpower Change' already exists, skipping.
# Trope 'Adaptational Sympathy' already exists, skipping.
# Trope 'Adaptational Timespan Change' already exists, skipping.
# Trope 'Adaptational Ugliness' already exists, skipping.
# Trope 'Adaptational Upbringing Change' already exists, skipping.
# Trope 'Adaptational Villainy' already exists, skipping.
# Trope 'Adaptational Wealth' already exists, skipping.
# Trope 'Adaptational Weapon Swap' already exists, skipping.
# Trope 'Adaptational Wimp' already exists, skipping.
# Trope 'Adaptation Amalgamation' already exists, skipping.
# Trope 'Adaptation Decay' already exists, skipping.
# Trope 'Adaptation Deviation' already exists, skipping.
# Trope 'Adaptation Displacement' already exists, skipping.
# Trope 'Adaptation Distillation' already exists, skipping.
# Trope 'Adaptation Drift' already exists, skipping.
# Trope 'Adaptation Dye Job' already exists, skipping.
# Trope 'Adaptation Expansion' already exists, skipping.
# Trope 'Adaptation Explanation Extrication' already exists, skipping.
# Trope 'Adaptation First' already exists, skipping.
# Trope 'Adaptation Induced Plot Hole' already exists, skipping.
# Trope 'Adaptation Inspiration' already exists, skipping.
# Trope 'Adaptation Name Change' already exists, skipping.
# Trope 'Adaptation Origin Connection' already exists, skipping.
# Trope 'Adaptation Overdosed' already exists, skipping.
# Trope 'Adaptation Personality Change' already exists, skipping.
# Trope 'Adaptation Relationship Overhaul' already exists, skipping.
# Trope 'Adaptation Sequence' already exists, skipping.
# Trope 'Adaptation Species Change' already exists, skipping.
# Trope 'Adaptation Title Change' already exists, skipping.
# Trope 'Adapted Out' already exists, skipping.
# Trope 'Adaptive Ability' already exists, skipping.
# Trope 'Adaptive Armor' already exists, skipping.
# Trope 'A Darker Me' already exists, skipping.
# Trope 'A Day In Her Apron' already exists, skipping.
# Trope 'A Day In The Limelight' already exists, skipping.
# Trope 'Ad Break Double Take' already exists, skipping.
# Trope 'Ad Bumpers' already exists, skipping.
# Trope 'Added Alliterative Appeal' already exists, skipping.
# Trope 'Addiction Displacement' already exists, skipping.
# Trope 'Addiction Powered' already exists, skipping.
# Trope 'Addiction Song' already exists, skipping.
# Trope 'Addictive Foreign Soap Opera' already exists, skipping.
# Trope 'Addictive Magic' already exists, skipping.
# Trope 'Ad Dissonance' already exists, skipping.
# Trope 'Addled Addict' already exists, skipping.
# Trope 'Addressing The Player' already exists, skipping.
# Trope 'A Deadly Affair' already exists, skipping.
# Trope 'A Death In The Limelight' already exists, skipping.
# Trope 'A Degree In Useless' already exists, skipping.
# Trope 'Ad Hominem' already exists, skipping.
# Trope 'A Dick In Name' already exists, skipping.
# Trope 'Adipose Rex' already exists, skipping.
# Trope 'Adjacent To This Complete Breakfast' already exists, skipping.
# Trope 'Adjective Animal Alehouse' already exists, skipping.
# Trope 'Adjective Noun Fred' already exists, skipping.
# Trope 'Adjustable Censorship' already exists, skipping.
# Trope 'Adminisphere' already exists, skipping.
# Trope 'Admiring The Abomination' already exists, skipping.
# Trope 'Admiring The Poster' already exists, skipping.
# Trope 'A Dog Ate My Homework' already exists, skipping.
# Trope 'A Dog Named Cat' already exists, skipping.
# Trope 'A Dog Named Dog' already exists, skipping.
# Trope 'A Dog Named Perro' already exists, skipping.
# Trope 'Adolf Hitlarious' already exists, skipping.
# Trope 'A Doormat To His Men' already exists, skipping.
# Trope 'Adopt A Servant' already exists, skipping.
# Trope 'Adopted Into Royalty' already exists, skipping.
# Trope 'Adopted To The House' already exists, skipping.
# Trope 'Adopting The Abused' already exists, skipping.
# Trope 'Adopting The Gender Binary' already exists, skipping.
# Trope 'Adoption Angst' already exists, skipping.
# Trope 'Adoption Conflict' already exists, skipping.
# Trope 'Adoption Diss' already exists, skipping.
# Trope 'Adoption Induced Pregnancy' already exists, skipping.
# Trope 'Adoption Is Not An Option' already exists, skipping.
# Trope 'Adoptive Name Change' already exists, skipping.
# Trope 'Adoptive Peer Parent' already exists, skipping.
# Trope 'Adopt The Dog' already exists, skipping.
# Trope 'Adopt The Food' already exists, skipping.
# Trope 'Adorable Abomination' already exists, skipping.
# Trope 'Adorable Evil Minions' already exists, skipping.
# Trope 'Adorable Fluffy Tail' already exists, skipping.
# Trope 'Adorably Precocious Child' already exists, skipping.
# Trope 'Adored By The Network' already exists, skipping.
# Trope 'Adoring The Pests' already exists, skipping.
# Trope 'Adorkable' already exists, skipping.
# Trope 'Adrenaline Makeover' already exists, skipping.
# Trope 'Adrenaline Time' already exists, skipping.
# Trope 'Ad Reward' already exists, skipping.
# Trope 'Adult Adoptee' already exists, skipping.
# Trope 'Adult Hater' already exists, skipping.
# Trope 'Adults Are More Anthropomorphic' already exists, skipping.
# Trope 'Adults Are Useless' already exists, skipping.
# Trope 'Adults Dressed As Children' already exists, skipping.
# Trope 'Adult Sleeps With Stuffed Toy' already exists, skipping.
# Trope 'A Dungeon Is You' already exists, skipping.
# Trope 'Advanced Ancient Acropolis' already exists, skipping.
# Trope 'Advanced Ancient Humans' already exists, skipping.
# Trope 'Advanced Civilization Hollow Imagination' already exists, skipping.
# Trope 'Advanced Movement Technique' already exists, skipping.
# Trope 'Advanced Tech 2000' already exists, skipping.
# Trope 'Advance Notice Crime' already exists, skipping.
# Trope 'Advancing Boss Of Doom' already exists, skipping.
# Trope 'Advancing Wall Of Doom' already exists, skipping.
# Trope 'Advantage Ball' already exists, skipping.
# Trope 'Adventure Duo' already exists, skipping.
# Trope 'Adventure Friendly World' already exists, skipping.
# Trope 'Adventure Guild' already exists, skipping.
# Trope 'Adventurer Archaeologist' already exists, skipping.
# Trope 'Adventure Rebuff' already exists, skipping.
# Trope 'Adventurer Outfit' already exists, skipping.
# Trope 'Adventurers Club' already exists, skipping.
# Trope 'Adventures In Comaland' already exists, skipping.
# Trope 'Adventures In The Bible' already exists, skipping.
# Trope 'Adventure Towns' already exists, skipping.
# Trope 'Adventurous Irish Violins' already exists, skipping.
# Trope 'Advertised Extra' already exists, skipping.
# Trope 'Advertisement Game' already exists, skipping.
# Trope 'Advertising' already exists, skipping.
# Trope 'Advertising By Association' already exists, skipping.
# Trope 'Advertising Campaigns' already exists, skipping.
# Trope 'Advertising Disguised As News' already exists, skipping.
# Trope 'Advertising Only Continuity' already exists, skipping.
# Trope 'Advert Overloaded Future' already exists, skipping.
# Trope 'Advice Backfire' already exists, skipping.
# Trope 'Aerial Canyon Chase' already exists, skipping.
# Trope 'Aerith And Bob' already exists, skipping.
# Trope 'Aerosol Flamethrower' already exists, skipping.
# Trope 'Aerosol Spray Backfire' already exists, skipping.
# Trope 'Aesop Amnesia' already exists, skipping.
# Trope 'Aesop Collateral Damage' already exists, skipping.
# Trope 'Aesop Enforcer' already exists, skipping.
# Trope 'Aesoptinum' already exists, skipping.
# Trope 'A Family Affair' already exists, skipping.
# Trope 'A Father To His Men' already exists, skipping.
# Trope 'A Fete Worse Than Death' already exists, skipping.
# Trope 'Affably Evil' already exists, skipping.
# Trope 'Affair Blame The Bastard' already exists, skipping.
# Trope 'Affair Hair' already exists, skipping.
# Trope 'Affair Letters' already exists, skipping.
# Trope 'Affectionate Gesture To The Head' already exists, skipping.
# Trope 'Affectionate Gesture To The Nose' already exists, skipping.
# Trope 'Affectionate Nickname' already exists, skipping.
# Trope 'Affectionate Parody' already exists, skipping.
# Trope 'Affectionate Pickpocket' already exists, skipping.
# Trope 'Affection Hating Kid' already exists, skipping.
# Trope 'Affirmative Action Girl' already exists, skipping.
# Trope 'Affirmative Action Legacy' already exists, skipping.
# Trope 'Affluent Ascetic' already exists, skipping.
# Trope 'A Fistful Of Rehashes' already exists, skipping.
# Trope 'A Foggy Day In London Town' already exists, skipping.
# Trope 'A Fool And His New Money Are Soon Parted' already exists, skipping.
# Trope 'A Fool For A Client' already exists, skipping.
# Trope 'A Form You Are Comfortable With' already exists, skipping.
# Trope 'Afraid Of Blood' already exists, skipping.
# Trope 'Afraid Of Clowns' already exists, skipping.
# Trope 'Afraid Of Doctors' already exists, skipping.
# Trope 'Afraid Of Needles' already exists, skipping.
# Trope 'Afraid Of Their Own Strength' already exists, skipping.
# Trope 'Afraid To Hold The Baby' already exists, skipping.
# Trope 'Africa Is A Country' already exists, skipping.
# Trope 'African Chant' already exists, skipping.
# Trope 'African Terrorists' already exists, skipping.
# Trope 'A Friend In Need' already exists, skipping.
# Trope 'Afro Asskicker' already exists, skipping.
# Trope 'Afrofuturism' already exists, skipping.
# Trope 'After Action Healing Drama' already exists, skipping.
# Trope 'After Action Patchup' already exists, skipping.
# Trope 'After Action Report' already exists, skipping.
# Trope 'After Action Villain Analysis' already exists, skipping.
# Trope 'After Boss Recovery' already exists, skipping.
# Trope 'After Combat Recovery' already exists, skipping.
# Trope 'Afterlife Angst' already exists, skipping.
# Trope 'Afterlife Antechamber' already exists, skipping.
# Trope 'Afterlife Avenger' already exists, skipping.
# Trope 'Afterlife Express' already exists, skipping.
# Trope 'Afterlife Of Service' already exists, skipping.
# Trope 'Afterlife Tour' already exists, skipping.
# Trope 'Afterlife Welcome' already exists, skipping.
# Trope 'After School Cleaning Duty' already exists, skipping.
# Trope 'Aftershow' already exists, skipping.
# Trope 'After The End' already exists, skipping.
# Trope 'Against My Religion' already exists, skipping.
# Trope 'Against The Grain' already exists, skipping.
# Trope 'Against The Setting Sun' already exists, skipping.
# Trope 'Again With Feeling' already exists, skipping.
# Trope 'Age Appropriate Angst' already exists, skipping.
# Trope 'Age Cut' already exists, skipping.
# Trope 'Age Down Romance' already exists, skipping.
# Trope 'Age Gap Algebra' already exists, skipping.
# Trope 'Age Gap Romance' already exists, skipping.
# Trope 'Age Inappropriate Art' already exists, skipping.
# Trope 'Age Inappropriate Dress' already exists, skipping.
# Trope 'Age Insecurity' already exists, skipping.
# Trope 'Age Is Relative' already exists, skipping.
# Trope 'Ageless Birthday Episode' already exists, skipping.
# Trope 'Age Lift' already exists, skipping.
# Trope 'Agent Mulder' already exists, skipping.
# Trope 'Agent Peacock' already exists, skipping.
# Trope 'Agent Provocateur' already exists, skipping.
# Trope 'Agent Scully' already exists, skipping.
# Trope 'Agents Dating' already exists, skipping.
# Trope 'Age Of Reptiles' already exists, skipping.
# Trope 'Age Of Titles' already exists, skipping.
# Trope 'Age Progression Song' already exists, skipping.
# Trope 'Age Stereotypical Food' already exists, skipping.
# Trope 'Age Without Youth' already exists, skipping.
# Trope 'Aggressive Categorism' already exists, skipping.
# Trope 'Aggressive Negotiations' already exists, skipping.
# Trope 'Aggressive Play Incentive' already exists, skipping.
# Trope 'Aggressive Submissive' already exists, skipping.
# Trope 'A Gift For Themselves' already exists, skipping.
# Trope 'Aging Would Be Hipster' already exists, skipping.
# Trope 'A Girl In Every Port' already exists, skipping.
# Trope 'Agitated Item Stomping' already exists, skipping.
# Trope 'A Glass In The Hand' already exists, skipping.
# Trope 'A Glass Of Chianti' already exists, skipping.
# Trope 'A Glitch In The Matrix' already exists, skipping.
# Trope 'A God Am I' already exists, skipping.
# Trope 'A God I Am Not' already exists, skipping.
# Trope 'A God Is You' already exists, skipping.
# Trope 'Agonizing Stomach Wound' already exists, skipping.
# Trope 'Agony Beam' already exists, skipping.
# Trope 'Agony Of The Feet' already exists, skipping.
# Trope 'A Good Name For A Rock Band' already exists, skipping.
# Trope 'A Good Old Fashioned Paint Watching' already exists, skipping.
# Trope 'A Good Way To Die' already exists, skipping.
# Trope 'Agree To Disagree' already exists, skipping.
# Trope 'Agri World' already exists, skipping.
# Trope 'A Handful For An Eye' already exists, skipping.
# Trope 'A Head At Each End' already exists, skipping.
# Trope 'A Hell Of A Time' already exists, skipping.
# Trope 'Ahem' already exists, skipping.
# Trope 'A Hero Is Born' already exists, skipping.
# Trope 'A Hero To His Hometown' already exists, skipping.
# Trope 'A Homeowner Is You' already exists, skipping.
# Trope 'A House Divided' already exists, skipping.
# Trope 'AI Breaker' already exists, skipping.
# Trope 'AI Cronym' already exists, skipping.
# Trope 'AI Generated Economy' already exists, skipping.
# Trope 'AI Getting High' already exists, skipping.
# Trope 'AI Is A Crapshoot' already exists, skipping.
# Trope 'Ailment Induced Cruelty' already exists, skipping.
# Trope 'Aim For The Horn' already exists, skipping.
# Trope 'Aimlessly Seeking Happiness' already exists, skipping.
# Trope 'Aint Too Proud To Beg' already exists, skipping.
# Trope 'Air Aided Acrobatics' already exists, skipping.
# Trope 'Airborne Aircraft Carrier' already exists, skipping.
# Trope 'Airborne Artillery' already exists, skipping.
# Trope 'Airborne Mook' already exists, skipping.
# Trope 'Air Dashing' already exists, skipping.
# Trope 'Air Guitar' already exists, skipping.
# Trope 'Air Hugging' already exists, skipping.
# Trope 'Air Jousting' already exists, skipping.
# Trope 'AI Roulette' already exists, skipping.
# Trope 'Airplane Arms' already exists, skipping.
# Trope 'Airplane Of Love' already exists, skipping.
# Trope 'Airport Novel' already exists, skipping.
# Trope 'Air Quotes' already exists, skipping.
# Trope 'Airstrike Impossible' already exists, skipping.
# Trope 'Airstrip One' already exists, skipping.
# Trope 'Air Vent Passageway' already exists, skipping.
# Trope 'Air Voyance' already exists, skipping.
# Trope 'AKA 47' already exists, skipping.
# Trope 'Akashic Records' already exists, skipping.
# Trope 'A Kind Of One' already exists, skipping.
# Trope 'A Lady On Each Arm' already exists, skipping.
# Trope 'A Lady Rides Aside' already exists, skipping.
# Trope 'Alan Smithee' already exists, skipping.
# Trope 'Alarm SOS' already exists, skipping.
# Trope 'Alas Poor Scrappy' already exists, skipping.
# Trope 'Alas Poor Villain' already exists, skipping.
# Trope 'Alas Poor Yorick' already exists, skipping.
# Trope 'Albinos Are Freaks' already exists, skipping.
# Trope 'Album Closure' already exists, skipping.
# Trope 'Album Filler' already exists, skipping.
# Trope 'Album Intro Track' already exists, skipping.
# Trope 'Album Single' already exists, skipping.
# Trope 'Album Title Drop' already exists, skipping.
# Trope 'Alchemic Elementals' already exists, skipping.
# Trope 'Alchemy Is Magic' already exists, skipping.
# Trope 'Alcohol Hic' already exists, skipping.
# Trope 'Alcoholic Parent' already exists, skipping.
# Trope 'Alcohol Induced Bisexuality' already exists, skipping.
# Trope 'Alcohol Induced Idiocy' already exists, skipping.
# Trope 'Alcohol Is Gasoline' already exists, skipping.
# Trope 'Alcubierre Drive' already exists, skipping.
# Trope 'Alertness Blink' already exists, skipping.
# Trope 'A Lesson In Defeat' already exists, skipping.
# Trope 'A Lesson Learned Too Well' already exists, skipping.
# Trope 'Algorithmic Story Branching' already exists, skipping.
# Trope 'Alice Allusion' already exists, skipping.
# Trope 'Alice And Bob' already exists, skipping.
# Trope 'Alien Abductees Fight Back' already exists, skipping.
# Trope 'Alien Abduction' already exists, skipping.
# Trope 'Alien Among Us' already exists, skipping.
# Trope 'Alien Animals' already exists, skipping.
# Trope 'Alien Arts Are Appreciated' already exists, skipping.
# Trope 'Alien Autopsy' already exists, skipping.
# Trope 'Alien Blood' already exists, skipping.
# Trope 'Alien Catnip' already exists, skipping.
# Trope 'Alien Episode' already exists, skipping.
# Trope 'Alien Fair Folk' already exists, skipping.
# Trope 'Alien Gender Confusion' already exists, skipping.
# Trope 'Alien Geometries' already exists, skipping.
# Trope 'Alien Hair' already exists, skipping.
# Trope 'Alien Invasion' already exists, skipping.
# Trope 'Alien Kudzu' already exists, skipping.
# Trope 'Alien Landmass' already exists, skipping.
# Trope 'Alien Non Interference Clause' already exists, skipping.
# Trope 'Alien Princess' already exists, skipping.
# Trope 'Aliens Are Bastards' already exists, skipping.
# Trope 'Alien Sea' already exists, skipping.
# Trope 'Aliens In Cardiff' already exists, skipping.
# Trope 'Alien Sky' already exists, skipping.
# Trope 'Aliens Love Human Food' already exists, skipping.
# Trope 'Aliens Made Them Do It' already exists, skipping.
# Trope 'Aliens Never Invented Democracy' already exists, skipping.
# Trope 'Aliens Never Invented The Wheel' already exists, skipping.
# Trope 'Aliens Of London' already exists, skipping.
# Trope 'Alien Space Bats' already exists, skipping.
# Trope 'Aliens Speaking English' already exists, skipping.
# Trope 'Aliens Steal Cable' already exists, skipping.
# Trope 'Aliens Steal Cattle' already exists, skipping.
# Trope 'A Lighter Shade Of Black' already exists, skipping.
# Trope 'A Lighter Shade Of Grey' already exists, skipping.
# Trope 'A Light In The Distance' already exists, skipping.
# Trope 'Alignment Based Endings' already exists, skipping.
# Trope 'Alike And Antithetical Adversaries' already exists, skipping.
# Trope 'A Little Something We Call Rock And Roll' already exists, skipping.
# Trope 'A Lizard Named Liz' already exists, skipping.
# Trope 'All Abusers Are Male' already exists, skipping.
# Trope 'All Accessible Magic' already exists, skipping.
# Trope 'All According To Plan' already exists, skipping.
# Trope 'All Amazons Want Hercules' already exists, skipping.
# Trope 'All American Face' already exists, skipping.
# Trope 'All Animals Are Dogs' already exists, skipping.
# Trope 'All Animals Are Domesticated' already exists, skipping.
# Trope 'All Animation Is Disney' already exists, skipping.
# Trope 'All Anime Is Naughty Tentacles' already exists, skipping.
# Trope 'All A Part Of The Job' already exists, skipping.
# Trope 'All Are Equal In Death' already exists, skipping.
# Trope 'All Asians Know Martial Arts' already exists, skipping.
# Trope 'All Asians Wear Conical Straw Hats' already exists, skipping.
# Trope 'All Balloons Have Helium' already exists, skipping.
# Trope 'All Beer Is Ale' already exists, skipping.
# Trope 'All Bikers Are Hells Angels' already exists, skipping.
# Trope 'All Cavemen Were Neanderthals' already exists, skipping.
# Trope 'All CGI Cartoon' already exists, skipping.
# Trope 'All Cheering All The Time' already exists, skipping.
# Trope 'All Chinese People Know Kung Fu' already exists, skipping.
# Trope 'All Cloth Unravels' already exists, skipping.
# Trope 'All Crimes Are Equal' already exists, skipping.
# Trope 'All Deaths Final' already exists, skipping.
# Trope 'All Deserts Have Cacti' already exists, skipping.
# Trope 'All Dogs Are Purebred' already exists, skipping.
# Trope 'All Drummers Are Animals' already exists, skipping.
# Trope 'Alleged Lookalikes' already exists, skipping.
# Trope 'Allegedly Dateless' already exists, skipping.
# Trope 'Allegedly Free Game' already exists, skipping.
# Trope 'Allegedly Optimistic Ending' already exists, skipping.
# Trope 'Allegiance Affirmation' already exists, skipping.
# Trope 'Allegorical Character' already exists, skipping.
# Trope 'Allegory' already exists, skipping.
# Trope 'Allegory Adventure' already exists, skipping.
# Trope 'All Elections Are Serious Business' already exists, skipping.
# Trope 'All Encompassing Mantle' already exists, skipping.
# Trope 'Allergic To Evil' already exists, skipping.
# Trope 'Allergic To Love' already exists, skipping.
# Trope 'Allergic To Routine' already exists, skipping.
# Trope 'All First Person Narrators Write Like Novelists' already exists, skipping.
# Trope 'All Flyers Are Birds' already exists, skipping.
# Trope 'All For Nothing' already exists, skipping.
# Trope 'All Gays Are Pedophiles' already exists, skipping.
# Trope 'All Gays Are Promiscuous' already exists, skipping.
# Trope 'All Gays Love Theater' already exists, skipping.
# Trope 'All Genes Are Codominant' already exists, skipping.
# Trope 'All Germans Are Nazis' already exists, skipping.
# Trope 'All Ghouls School' already exists, skipping.
# Trope 'All Girls Like Ponies' already exists, skipping.
# Trope 'All Girls Want Bad Boys' already exists, skipping.
# Trope 'All Gravity Is The Same' already exists, skipping.
# Trope 'All Grown Up Remark' already exists, skipping.
# Trope 'All Guys Want Cheerleaders' already exists, skipping.
# Trope 'All Guys Want Sorority Women' already exists, skipping.
# Trope 'All Hail The Great God Mickey' already exists, skipping.
# Trope 'Alliance Meter' already exists, skipping.
# Trope 'Alliance Of Alternates' already exists, skipping.
# Trope 'Alliance Of Revenge' already exists, skipping.
# Trope 'Alliance With An Abomination' already exists, skipping.
# Trope 'All In A Row' already exists, skipping.
# Trope 'All In The Eyes' already exists, skipping.
# Trope 'All Issues Are Political Issues' already exists, skipping.
# Trope 'All Is Well That Ends Well' already exists, skipping.
# Trope 'Alliteration And Adventurers' already exists, skipping.
# Trope 'Alliterative Family' already exists, skipping.
# Trope 'Alliterative List' already exists, skipping.
# Trope 'Alliterative Name' already exists, skipping.
# Trope 'Alliterative Title' already exists, skipping.
# Trope 'All Jews Are Ashkenazi' already exists, skipping.
# Trope 'All Jews Are Cheapskates' already exists, skipping.
# Trope 'All Just A Dream' already exists, skipping.
# Trope 'All Just A Prank' already exists, skipping.
# Trope 'All Knowing Singing Narrator' already exists, skipping.
# Trope 'All Lesbians Want Kids' already exists, skipping.
# Trope 'All Love Is Unrequited' already exists, skipping.
# Trope 'All Loving Hero' already exists, skipping.
# Trope 'All Lowercase Letters' already exists, skipping.
# Trope 'All Men Are Perverts' already exists, skipping.
# Trope 'All Monks Know Kung Fu' already exists, skipping.
# Trope 'All Musicals Are Adaptations' already exists, skipping.
# Trope 'All Muslims Are Arab' already exists, skipping.
# Trope 'All Myths Are True' already exists, skipping.
# Trope 'All Nations Are Superpowers' already exists, skipping.
# Trope 'All Natural Fire Extinguisher' already exists, skipping.
# Trope 'All Natural Gem Polish' already exists, skipping.
# Trope 'All Natural Snake Oil' already exists, skipping.
# Trope 'All Of Them' already exists, skipping.
# Trope 'All Of The Other Reindeer' already exists, skipping.
# Trope 'All Of Time At Once' already exists, skipping.
# Trope 'Allohistorical Allusion' already exists, skipping.
# Trope 'All Or Nothing' already exists, skipping.
# Trope 'All Or Nothing Reloads' already exists, skipping.
# Trope 'Allowed Internal War' already exists, skipping.
# Trope 'All Part Of The Show' already exists, skipping.
# Trope 'All Periods Are PMS' already exists, skipping.
# Trope 'All Planets Are Earth Like' already exists, skipping.
# Trope 'All Powerful Bystander' already exists, skipping.
# Trope 'All Psychology Is Freudian' already exists, skipping.
# Trope 'All Star Cast' already exists, skipping.
# Trope 'All Stereotype Cast' already exists, skipping.
# Trope 'All Swords Are The Same' already exists, skipping.
# Trope 'All Take And No Give' already exists, skipping.
# Trope 'All That Glitters' already exists, skipping.
# Trope 'All The Good Men Are Gay' already exists, skipping.
# Trope 'All Theories Are True' already exists, skipping.
# Trope 'All Therapists Are Muggles' already exists, skipping.
# Trope 'All There In The Manual' already exists, skipping.
# Trope 'All There In The Script' already exists, skipping.
# Trope 'All There In The Stinger' already exists, skipping.
# Trope 'All The Worlds Are A Stage' already exists, skipping.
# Trope 'All Trolls Are Different' already exists, skipping.
# Trope 'All Up To You' already exists, skipping.
# Trope 'Alluring Flowers' already exists, skipping.
# Trope 'All Webbed Up' already exists, skipping.
# Trope 'All Wishes Granted' already exists, skipping.
# Trope 'All Witches Have Cats' already exists, skipping.
# Trope 'All Women Are Lustful' already exists, skipping.
# Trope 'All Women Are Prudes' already exists, skipping.
# Trope 'All Women Hate Each Other' already exists, skipping.
# Trope 'All Women Love Shoes' already exists, skipping.
# Trope 'All Work Vs All Play' already exists, skipping.
# Trope 'All Your Base Are Belong To Us' already exists, skipping.
# Trope 'All Your Colors Combined' already exists, skipping.
# Trope 'All Your Powers Combined' already exists, skipping.
# Trope 'Alma Mater Song' already exists, skipping.
# Trope 'Almighty Idiot' already exists, skipping.
# Trope 'Almighty Janitor' already exists, skipping.
# Trope 'Almighty Mom' already exists, skipping.
# Trope 'Almost Dead Guy' already exists, skipping.
# Trope 'Almost Famous Name' already exists, skipping.
# Trope 'Almost Holding Hands' already exists, skipping.
# Trope 'Almost Kiss' already exists, skipping.
# Trope 'Almost Lethal Weapons' already exists, skipping.
# Trope 'Almost Out Of Oxygen' already exists, skipping.
# Trope 'Alone Among Families' already exists, skipping.
# Trope 'Alone Among The Couples' already exists, skipping.
# Trope 'Alone In A Crowd' already exists, skipping.
# Trope 'Alone With Prisoner Ploy' already exists, skipping.
# Trope 'Alone With The Psycho' already exists, skipping.
# Trope 'A Long Time Ago In A Galaxy Far Far Away' already exists, skipping.
# Trope 'Aloof Ally' already exists, skipping.
# Trope 'Aloof Archer' already exists, skipping.
# Trope 'Aloof Big Brother' already exists, skipping.
# Trope 'Aloof Dark Haired Girl' already exists, skipping.
# Trope 'Aloof Leader Affable Subordinate' already exists, skipping.
# Trope 'A Love To Dismember' already exists, skipping.
# Trope 'Alpha And Beta Wolves' already exists, skipping.
# Trope 'Alphabet Architecture' already exists, skipping.
# Trope 'Alphabetical Theme Naming' already exists, skipping.
# Trope 'Alphabet News Network' already exists, skipping.
# Trope 'Alphabet Song' already exists, skipping.
# Trope 'Alphabet Soup Cans' already exists, skipping.
# Trope 'Alpha Bitch' already exists, skipping.
# Trope 'Alpha Strike' already exists, skipping.
# Trope 'Already Done For You' already exists, skipping.
# Trope 'Already Met Everyone' already exists, skipping.
# Trope 'Already The Case' already exists, skipping.
# Trope 'Already Undone For You' already exists, skipping.
# Trope 'Altar Diplomacy' already exists, skipping.
# Trope 'Altar The Speed' already exists, skipping.
# Trope 'Alter Ego Acting' already exists, skipping.
# Trope 'Alter Kocker' already exists, skipping.
# Trope 'Alternate Aesop Interpretation' already exists, skipping.
# Trope 'Alternate Album Cover' already exists, skipping.
# Trope 'Alternate Animal Affection' already exists, skipping.
# Trope 'Alternate Catchphrase Inflection' already exists, skipping.
# Trope 'Alternate Character Reading' already exists, skipping.
# Trope 'Alternate Company Equivalent' already exists, skipping.
# Trope 'Alternate Continuity' already exists, skipping.
# Trope 'Alternate DVD Commentary' already exists, skipping.
# Trope 'Alternate History' already exists, skipping.
# Trope 'Alternate History Dinosaur Survival' already exists, skipping.
# Trope 'Alternate History Nazi Victory' already exists, skipping.
# Trope 'Alternate History Wank' already exists, skipping.
# Trope 'Alternate Identity Amnesia' already exists, skipping.
# Trope 'Alternate Landmark History' already exists, skipping.
# Trope 'Alternate Monochrome Version' already exists, skipping.
# Trope 'Alternate Music Video' already exists, skipping.
# Trope 'Alternate Personality Punishment' already exists, skipping.
# Trope 'Alternate Reality Episode' already exists, skipping.
# Trope 'Alternate Reality Game' already exists, skipping.
# Trope 'Alternate Self' already exists, skipping.
# Trope 'Alternate Self Shipping' already exists, skipping.
# Trope 'Alternate Show Interpretation' already exists, skipping.
# Trope 'Alternate Species Counterpart' already exists, skipping.
# Trope 'Alternate Techline' already exists, skipping.
# Trope 'Alternate Timeline' already exists, skipping.
# Trope 'Alternate Timeline Ancestry' already exists, skipping.
# Trope 'Alternate Tooniverse' already exists, skipping.
# Trope 'Alternate Universe' already exists, skipping.
# Trope 'Alternate Universe Fic' already exists, skipping.
# Trope 'Alternate Universe Reed Richards Is Awesome' already exists, skipping.
# Trope 'Alternate World Map' already exists, skipping.
# Trope 'Alternative Calendar' already exists, skipping.
# Trope 'Alternative Character Interpretation' already exists, skipping.
# Trope 'Alternative Comics' already exists, skipping.
# Trope 'Alternative Dance' already exists, skipping.
# Trope 'Alternative Foreign Theme Song' already exists, skipping.
# Trope 'Alternative Hip Hop' already exists, skipping.
# Trope 'Alternative Joke Interpretation' already exists, skipping.
# Trope 'Alternative Metal' already exists, skipping.
# Trope 'Alternative Number System' already exists, skipping.
# Trope 'Alternative Rock' already exists, skipping.
# Trope 'Alternative Self Name Change' already exists, skipping.
# Trope 'Alternative Turing Test' already exists, skipping.
# Trope 'Altitis' already exists, skipping.
# Trope 'Alto Villainess' already exists, skipping.
# Trope 'Alt Text' already exists, skipping.
# Trope 'Alucard' already exists, skipping.
# Trope 'Aluminum Christmas Trees' already exists, skipping.
# Trope 'Always A Bigger Fish' already exists, skipping.
# Trope 'Always Accurate Attack' already exists, skipping.
# Trope 'Always A Child To Parent' already exists, skipping.
# Trope 'Always A Live Transmission' already exists, skipping.
# Trope 'Always Camp' already exists, skipping.
# Trope 'Always Chaotic Evil' already exists, skipping.
# Trope 'Always Check Behind The Chair' already exists, skipping.
# Trope 'Always Close' already exists, skipping.
# Trope 'Always Gets His Man' already exists, skipping.
# Trope 'Always Identical Twins' already exists, skipping.
# Trope 'Always In Class One' already exists, skipping.
# Trope 'Always Introduces Themselves' already exists, skipping.
# Trope 'Always Know A Pilot' already exists, skipping.
# Trope 'Always Late' already exists, skipping.
# Trope 'Always Lawful Good' already exists, skipping.
# Trope 'Always Murder' already exists, skipping.
# Trope 'Always Need What You Gave Up' already exists, skipping.
# Trope 'Always Night' already exists, skipping.
# Trope 'Always On Duty' already exists, skipping.
# Trope 'Always Over The Shoulder' already exists, skipping.
# Trope 'Always Save The Girl' already exists, skipping.
# Trope 'Always Second Best' already exists, skipping.
# Trope 'Always Someone Better' already exists, skipping.
# Trope 'Always With You' already exists, skipping.
# Trope 'A Mac Guffin Full Of Money' already exists, skipping.
# Trope 'A Magic Contract Comes With A Kiss' already exists, skipping.
# Trope 'Amalgamated Individual' already exists, skipping.
# Trope 'A Man Is Always Eager' already exists, skipping.
# Trope 'A Master Makes Their Own Tools' already exists, skipping.
# Trope 'A Match Made In Stockholm' already exists, skipping.
# Trope 'Amateur Cast' already exists, skipping.
# Trope 'Amateur Film Making Plot' already exists, skipping.
# Trope 'Amateur Sleuth' already exists, skipping.
# Trope 'Amazing Freaking Grace' already exists, skipping.
# Trope 'Amazingly Embarrassing Parents' already exists, skipping.
# Trope 'Amazing Technicolor Battlefield' already exists, skipping.
# Trope 'Amazing Technicolor Population' already exists, skipping.
# Trope 'Amazing Technicolor Wildlife' already exists, skipping.
# Trope 'Amazing Technicolor World' already exists, skipping.
# Trope 'Amazon Brigade' already exists, skipping.
# Trope 'Amazon Chaser' already exists, skipping.
# Trope 'Amazonian Beauty' already exists, skipping.
# Trope 'Ambadassador' already exists, skipping.
# Trope 'Ambidextrous Sprite' already exists, skipping.
# Trope 'Ambient' already exists, skipping.
# Trope 'Ambiguous Clone Ending' already exists, skipping.
# Trope 'Ambiguous Criminal History' already exists, skipping.
# Trope 'Ambiguous Ending' already exists, skipping.
# Trope 'Ambiguous Family Ties' already exists, skipping.
# Trope 'Ambiguous Gender' already exists, skipping.
# Trope 'Ambiguous Gender Identity' already exists, skipping.
# Trope 'Ambiguous Innocence' already exists, skipping.
# Trope 'Ambiguously Absent Parent' already exists, skipping.
# Trope 'Ambiguously Bi' already exists, skipping.
# Trope 'Ambiguously Brown' already exists, skipping.
# Trope 'Ambiguously Christian' already exists, skipping.
# Trope 'Ambiguously Evil' already exists, skipping.
# Trope 'Ambiguously Gay' already exists, skipping.
# Trope 'Ambiguously Human' already exists, skipping.
# Trope 'Ambiguously Jewish' already exists, skipping.
# Trope 'Ambiguously Related' already exists, skipping.
# Trope 'Ambiguously Sentient Object' already exists, skipping.
# Trope 'Ambiguously Trained' already exists, skipping.
# Trope 'Ambiguous Robots' already exists, skipping.
# Trope 'Ambiguous Situation' already exists, skipping.
# Trope 'Ambiguous Start Of Darkness' already exists, skipping.
# Trope 'Ambiguous Syntax' already exists, skipping.
# Trope 'Ambiguous Time Period' already exists, skipping.
# Trope 'Ambition Is Evil' already exists, skipping.
# Trope 'Ambitious But Lazy' already exists, skipping.
# Trope 'Ambivalent Anglican' already exists, skipping.
# Trope 'Ambulance Chaser' already exists, skipping.
# Trope 'Ambulance Cut' already exists, skipping.
# Trope 'Ambushing Enemy' already exists, skipping.
# Trope 'A Mech By Any Other Name' already exists, skipping.
# Trope 'Amen Break' already exists, skipping.
# Trope 'America Is Still A Colony' already exists, skipping.
# Trope 'American Eagle' already exists, skipping.
# Trope 'American Gothic Couple' already exists, skipping.
# Trope 'American Kirby Is Hardcore' already exists, skipping.
# Trope 'American Robot' already exists, skipping.
# Trope 'Americans Are Cowboys' already exists, skipping.
# Trope 'Americans Hate Tingle' already exists, skipping.
# Trope 'American Title' already exists, skipping.
# Trope 'America Saves The Day' already exists, skipping.
# Trope 'Americasia' already exists, skipping.
# Trope 'America Takes Over The World' already exists, skipping.
# Trope 'America Won World War II' already exists, skipping.
# Trope 'AMFM Characterization' already exists, skipping.
# Trope 'Amicable Ants' already exists, skipping.
# Trope 'Amicable Exes' already exists, skipping.
# Trope 'Am I Just A Toy To You' already exists, skipping.
# Trope 'A Million Is A Statistic' already exists, skipping.
# Trope 'A Mind Is A Terrible Thing To Read' already exists, skipping.
# Trope 'A Minor Kidroduction' already exists, skipping.
# Trope 'Am I Right' already exists, skipping.
# Trope 'A Mischief Of Mice' already exists, skipping.
# Trope 'A Mistake Is Born' already exists, skipping.
# Trope 'Ammo Using Melee Weapon' already exists, skipping.
# Trope 'Ammunition Backpack' already exists, skipping.
# Trope 'Ammunition Conservation' already exists, skipping.
# Trope 'Amnesiac Costume Identity' already exists, skipping.
# Trope 'Amnesiac Dissonance' already exists, skipping.
# Trope 'Amnesiac God' already exists, skipping.
# Trope 'Amnesiac Hero' already exists, skipping.
# Trope 'Amnesiac Liar' already exists, skipping.
# ...
# Successfully processed and saved: Coincidental Dodge
# Successfully processed and saved: Coin On A String Trick
# Successfully processed and saved: Coins For The Dead
# Successfully processed and saved: Coin Targeting Trickshot
# Successfully processed and saved: Coin Walk Flexing
# Successfully processed and saved: Coitus Uninterruptus
# Successfully processed and saved: Colbert Bump
# Successfully processed and saved: Cold Blooded Torture
# Successfully processed and saved: Cold Blooded Whatever
# Successfully processed and saved: Cold Cash
# Successfully processed and saved: Cold Equation
# Successfully processed and saved: Cold Flames
# Successfully processed and saved: Cold Ham
# Successfully processed and saved: Cold Iron
# Successfully processed and saved: Cold Reading
# Successfully processed and saved: Cold Sleep Cold Future
# Successfully processed and saved: Cold Snap
# Successfully processed and saved: Cold Sniper
# Successfully processed and saved: Cold Touch Surprise
# Successfully processed and saved: Cold Turkeys Are Everywhere
# Successfully processed and saved: Collapsed Mid Speech
# Successfully processed and saved: Collapsible Helmet
# No example descriptions found.
# 0
# Successfully processed and saved: Collapsing Ceiling Boss
# Successfully processed and saved: Collapsing Lair
# Successfully processed and saved: Collared By Fashion
# Successfully processed and saved: Collateral Angst
# Successfully processed and saved: Collateral Damage
# No example descriptions found.
# 0
# Successfully processed and saved: Collection Sidequest
# Successfully processed and saved: Collective Death Glare
# Successfully processed and saved: Collective Groan
# Successfully processed and saved: Collective Identity
# Successfully processed and saved: Collector Of Forms
# Successfully processed and saved: Collector Of The Strange
# Successfully processed and saved: College Is High School Part 2
# Successfully processed and saved: College Radio
# No example descriptions found.
# 0
# Successfully processed and saved: College Widow
# Successfully processed and saved: Colliding Criminal Conspiracies
# Successfully processed and saved: Collision Damage
# Successfully processed and saved: Colon Cancer
# Successfully processed and saved: Colonel Badass
# Successfully processed and saved: Colonel Bogey March
# Successfully processed and saved: Colonel Kilgore
# Successfully processed and saved: Colonel Kurtz Copy
# Successfully processed and saved: Colonized Solar System
# No example descriptions found.
# 0
# Successfully processed and saved: Colony Drop
# Successfully processed and saved: Colony Ship
# Successfully processed and saved: Color Animal Codename
# Successfully processed and saved: Colorblind Casting
# Successfully processed and saved: Colorblind Confusion
# No example descriptions found.
# 0
# Successfully processed and saved: Colorblind Mode
# No example descriptions found.
# 0
# Successfully processed and saved: Color Character
# Successfully processed and saved: Color Coded Armies
# Successfully processed and saved: Color Coded Castes
# Successfully processed and saved: Color Coded Characters
# Successfully processed and saved: Color Coded Elements
# Successfully processed and saved: Color Coded Eyes
# Successfully processed and saved: Color Coded Item Tiers
# Successfully processed and saved: Color Coded Multiplayer
# Successfully processed and saved: Color Coded Patrician
# Successfully processed and saved: Color Coded Secret Identity
# Successfully processed and saved: Color Coded Speech
# Successfully processed and saved: Color Coded Stones
# Successfully processed and saved: Color Coded Wizardry
# Successfully processed and saved: Color Contrast
# Successfully processed and saved: Color Failure
# Successfully processed and saved: Colorful Contrails
# Successfully processed and saved: Colorful Song
# Successfully processed and saved: Coloring In The World
# Successfully processed and saved: Colorization
# Successfully processed and saved: Color Me Black
# Successfully processed and saved: Color Motif
# Successfully processed and saved: Color Wash
# Successfully processed and saved: Colossus Climb
# Successfully processed and saved: Colour Coded Emotions
# Successfully processed and saved: Colour Coded For Your Convenience
# Successfully processed and saved: Colour Coded Timestop
# Successfully processed and saved: Colourful Theme Naming
# Successfully processed and saved: Comatose Canary
# Successfully processed and saved: Combat Aestheticist
# Successfully processed and saved: Combat And Support
# Successfully processed and saved: Combatant Cooldown System
# Successfully processed and saved: Combat Breakdown
# Successfully processed and saved: Combat By Champion
# Successfully processed and saved: Combat Clairvoyance
# Successfully processed and saved: Combat Commentator
# Successfully processed and saved: Combat Compliment
# Successfully processed and saved: Combat Cue Stick
# No example descriptions found.
# 0
# Successfully processed and saved: Combat Diplomacy Stealth
# Successfully processed and saved: Combat Drugs
# No example descriptions found.
# 0
# Successfully processed and saved: Combat Exclusive Healing
# Successfully processed and saved: Combat Haircomb
# Successfully processed and saved: Combat Hand Fan
# No example descriptions found.
# 0
# Successfully processed and saved: Combat Medic
# Successfully processed and saved: Combat Parkour
# Successfully processed and saved: Combat Pragmatist
# Successfully processed and saved: Combat Referee
# Successfully processed and saved: Combat Resuscitation
# Successfully processed and saved: Combat Sadomasochist
# Successfully processed and saved: Combat Stilettos
# Successfully processed and saved: Combat Tentacles
# Successfully processed and saved: Combat Uninterruptus
# Successfully processed and saved: Combination Attack
# Successfully processed and saved: Combinatorial Explosion
# Successfully processed and saved: Combined Energy Attack
# Successfully processed and saved: Combining Mecha
# Successfully processed and saved: Combo Breaker
# Successfully processed and saved: Combo Platter Powers
# Successfully processed and saved: Combo Rifle
# Successfully processed and saved: Combos
# Successfully processed and saved: Come Alone
# Successfully processed and saved: Comeback Mechanic
# No example descriptions found.
# 0
# Successfully processed and saved: Come Back My Pet
# Successfully processed and saved: Come Back To Bed Honey
# Successfully processed and saved: Comeback Tomorrow
# Successfully processed and saved: Comedic Hero
# No example descriptions found.
# 0
# Successfully processed and saved: Comedic Lolicon
# Successfully processed and saved: Comedic Sociopathy
# Successfully processed and saved: Comedic Spanking
# Successfully processed and saved: Comedic Strangling
# Successfully processed and saved: Comedic Underwear Exposure
# Successfully processed and saved: Comedic Work Serious Scene
# No example descriptions found.
# 0
# Successfully processed and saved: Comedy
# Successfully processed and saved: Comedy As A Weapon
# Successfully processed and saved: Comedy Ghetto
# Successfully processed and saved: Come For The Game Stay For The Mods
# Successfully processed and saved: Come Out Come Out Wherever You Are
# Successfully processed and saved: Comet Of Doom
# Successfully processed and saved: Come To Gawk
# Successfully processed and saved: Come With Me If You Want To Live
# Successfully processed and saved: Comfort Food
# Successfully processed and saved: Comforting Comforter
# Successfully processed and saved: Comforting The Widow
# Successfully processed and saved: Comfort The Dying
# Successfully processed and saved: Comical Angry Face
# Successfully processed and saved: Comical Coffee Cup
# Successfully processed and saved: Comically Cross Eyed
# Successfully processed and saved: Comically Inappropriate Funeral Urn
# Successfully processed and saved: Comically Inept Healing
# Successfully processed and saved: Comically Invincible Hero
# Successfully processed and saved: Comically Lopsided Rivalry
# Successfully processed and saved: Comically Missing The Point
# Successfully processed and saved: Comically Oversized Butt
# Successfully processed and saved: Comically Small Bribe
# Successfully processed and saved: Comically Small Demand
# Successfully processed and saved: Comically Wordy Contract
# Successfully processed and saved: Comical Nap Drool
# Successfully processed and saved: Comical Overreacting
# No example descriptions found.
# 0
# Successfully processed and saved: Comical Translation
# Successfully processed and saved: Comic Book Adaptation
# Successfully processed and saved: Comic Book Fantasy Casting
# Successfully processed and saved: Comic Book Limbo
# Successfully processed and saved: Comic Book Movies Dont Use Codenames
# Successfully processed and saved: Comic Books Are Real
# No example descriptions found.
# 0
# Successfully processed and saved: Comic Books Of The1980s
# Successfully processed and saved: Comic Book Time
# Successfully processed and saved: Comic Role Play
# Successfully processed and saved: Comics Merger
# Successfully processed and saved: Comic Sutra
# Successfully processed and saved: Comic Trio
# Successfully processed and saved: Coming And Going
# Successfully processed and saved: Coming In Hot
# Successfully processed and saved: Coming Of Age Queer Romance
# Successfully processed and saved: Coming Of Age Story
# Successfully processed and saved: Coming Out Story
# No example descriptions found.
# 0
# Successfully processed and saved: Coming Out To Spouse
# Successfully processed and saved: Coming Straight Story
# No example descriptions found.
# 0
# Successfully processed and saved: Command And Conquer Economy
# Successfully processed and saved: Commander Contrarian
# Successfully processed and saved: Commanding Coolness
# Successfully processed and saved: Command Roster
# Successfully processed and saved: Commedia Dell Arte
# Successfully processed and saved: Commended For Pushback
# Successfully processed and saved: Commercial Break Cliffhanger
# Successfully processed and saved: Commercialized Christmas
# Successfully processed and saved: Commercial Pop Up
# Successfully processed and saved: Commercial Switcheroo
# Successfully processed and saved: Commie Land
# Successfully processed and saved: Commie Nazis
# Successfully processed and saved: Commissar Cap
# Successfully processed and saved: Commitment Anxiety
# Successfully processed and saved: Commitment Issues
# Successfully processed and saved: Comm Links
# Successfully processed and saved: Commonality Connection
# No example descriptions found.
# 0
# Successfully processed and saved: Common Character Classes
# Successfully processed and saved: Common Crossover
# Successfully processed and saved: Common Hollywood Sex Traits
# Successfully processed and saved: Common HTTP Status Code
# Successfully processed and saved: Common Knowledge
# Successfully processed and saved: Common Law Marriage
# No example descriptions found.
# 0
# Successfully processed and saved: Common Mary Sue Traits
# Successfully processed and saved: Common Meter
# No example descriptions found.
# 0
# Successfully processed and saved: Common Nonsense Jury
# Successfully processed and saved: Commonplace Rare
# Successfully processed and saved: Com Mons
# No example descriptions found.
# 0
# Successfully processed and saved: Common Tactical Gameplay Elements
# No example descriptions found.
# 0
# Successfully processed and saved: Common Time
# Successfully processed and saved: Common Tongue
# Successfully processed and saved: Commune
# Successfully processed and saved: Communications Officer
# Successfully processed and saved: Community Threatening Construction
# Successfully processed and saved: Commuting On A Bus
# Successfully processed and saved: Compact Infiltrator
# Successfully processed and saved: Companion Cube
# Successfully processed and saved: Companion Food
# No example descriptions found.
# 0
# Successfully processed and saved: Companion Show
# Successfully processed and saved: Companion Specific Sidequest
# Successfully processed and saved: Company Cameo
# Successfully processed and saved: Company Credit Card Abuse
# Successfully processed and saved: Company Cross References
# Successfully processed and saved: Company Town
# Successfully processed and saved: Compartment Shot
# Successfully processed and saved: Compassionate Critic
# Successfully processed and saved: Compelling Voice
# Successfully processed and saved: Compensated Dating
# Successfully processed and saved: Compensating For Something
# Successfully processed and saved: Compete For The Maidens Hand
# Successfully processed and saved: Competence Porn
# Successfully processed and saved: Competence Zone
# Successfully processed and saved: Competing Product Potshot
# Successfully processed and saved: Competing With A Corpse
# Successfully processed and saved: Competition Coupon Madness
# Successfully processed and saved: Competition Freak
# No example descriptions found.
# 0
# Successfully processed and saved: Competitive Balance
# No example descriptions found.
# 0
# Successfully processed and saved: Competitive Multiplayer
# Successfully processed and saved: Compilation Movie
# Successfully processed and saved: Compilation Rerelease
# Successfully processed and saved: Complacent Gaming Syndrome
# Successfully processed and saved: Complaining About Complaining
# Successfully processed and saved: Complaining About People Not Liking The Show
# Successfully processed and saved: Complaining About Rescues They Dont Like
# Successfully processed and saved: Complaining About Shows You Dont Watch
# No example descriptions found.
# 0
# Successfully processed and saved: Complaining About Things You Havent Paid For
# Successfully processed and saved: Complete Immortality
# Successfully processed and saved: Completely Different Title
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-033db76faff4> in <cell line: 1>()
# ----> 1 parsing_with_csv_aid(df_copy, output_folder, "test")
#
# <ipython-input-6-f5ca8a4fcd17> in parsing_with_csv_aid(df, output_folder, message)
#      20       output_df = pd.concat([output_df, pd.DataFrame([row])])
#      21
# ---> 22       output_df.to_csv(output_folder, index=False)
#      23       print(f"Successfully processed and saved: {name}")
#      24
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3900         )
#    3901
# -> 3902         return DataFrameRenderer(formatter).to_csv(
#    3903             path_or_buf,
#    3904             lineterminator=lineterminator,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1150             formatter=self.fmt,
#    1151         )
# -> 1152         csv_formatter.save()
#    1153
#    1154         if created_buffer:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in save(self)
#     264             )
#     265
# --> 266             self._save()
#     267
#     268     def _save(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in _save(self)
#     269         if self._need_to_save_header:
#     270             self._save_header()
# --> 271         self._save_body()
#     272
#     273     def _save_header(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in _save_body(self)
#     307             if start_i >= end_i:
#     308                 break
# --> 309             self._save_chunk(start_i, end_i)
#     310
#     311     def _save_chunk(self, start_i: int, end_i: int) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in _save_chunk(self, start_i, end_i)
#     318
#     319         ix = self.data_index[slicer]._format_native_types(**self._number_format)
# --> 320         libwriters.write_csv_rows(
#     321             data,
#     322             ix,
#
# writers.pyx in pandas._libs.writers.write_csv_rows()
#
# KeyboardInterrupt:

# %%
df_copy[['trope_description', 'related_link_names','related_links']] = df_copy['trope_link'].apply(parsing_trope_page).apply(pd.Series)
# Out:
# Streaming output truncated to the last 5000 lines.
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumanoidAliens
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumanoidFemaleAnimal
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumanOutsideAlienInside
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumanPackMule
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumanPet
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumanPincushion
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumanPopsicle
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumanResources
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumanSacrifice
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumansAdvanceSwiftly
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumansAreAverage
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumansAreBastards
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumansAreCthulhu
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumansAreDiplomats
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumansAreDivided
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumansAreFlawed
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumansAreGood
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumansAreInsects
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumansAreLeaders
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumansAreMorons
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumansAreNotTheDominantSpecies
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumansArePsychicInTheFuture
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumansAreSmelly
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumansAreSpecial
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumansAreSurvivors
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumansAreTheRealMonsters
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumansAreUgly
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumansAreWarriors
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumansAreWhite
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumansByAnyOtherName
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumanShield
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/Humanshifting
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumansKillWantonly
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumansNeedAliens
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumanSnowball
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumanSnowman
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumansThroughAlienEyes
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumanSubspecies
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumanToWerewolfFootprints
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumanTrafficJam
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumanTraffickers
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumanWeapon
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumbleBeginnings
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumbleGoal
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumbleHero
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumbleParentSpoiledKids
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumblePie
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumiliatingWager
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumiliationConga
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HummerDinger
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumongousHeadedHammer
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumongousMecha
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HuMons
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumorDissonance
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumoresqueProgression
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumorlessAliens
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HumorMode
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HundredPercentCompletion
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HundredPercentHeroismRating
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HungerCausesLethargy
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HungryJungle
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HungryMenace
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HungryWeapon
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/Hunk
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HunterOfHisOwnKind
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HunterOfMonsters
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HunterTrapper
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HuntingAccident
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HuntingIsEvil
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HuntingTheMostDangerousGame
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HuntingTheRogue
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HurlItIntoTheSun
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HurricaneKick
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HurricaneOfAphorisms
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HurricaneOfEuphemisms
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HurricaneOfExcuses
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HurricaneOfPuns
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HurryingHomeForTheHolidays
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HurtComfortFic
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HurtFootHop
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HuskyRusskie
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/Hustler
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HustlingTheMark
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HybridAllAlong
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HybridGenre
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HybridizationPlot
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HybridMonster
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HybridOverkillAvoidance
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HybridPower
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HybridsAreACrapshoot
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HydePlaysJekyll
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HydrantGeyser
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HydraProblem
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HydroElectroCombo
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HymnToMusic
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HypeAversion
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HypeBacklash
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HyperactiveMetabolism
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HyperactiveSprite
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/Hyperaffixation
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HyperAwareness
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HyperCompetentSidekick
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HyperDestructiveBouncingBall
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HyperlinkStory
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/Hyperpop
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HyperspaceArsenal
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HyperspaceHolmesHat
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HyperspaceIsAScaryPlace
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HyperspaceLanes
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HyperspaceMallet
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HyperspaceWardrobe
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HyperspeedAmbush
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HyperspeedEscape
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HyperventilationBag
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HypnoFool
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HypnoPendulum
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HypnoRay
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HypnosisProofDogs
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HypnoticCreature
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HypnoticEyes
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HypnoticHead
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HypnotismReversal
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HypnotizeTheCaptive
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HypnoTrinket
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/Hypochondria
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HypocrisyNod
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/Hypocrite
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HypocriteHasAPoint
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HypocriticalHeartwarming
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HypocriticalHumor
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HypocriticalSinging
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HypotheticalCasting
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HypotheticalFightDebate
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/Hysteria
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/HystericalWoman
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IaijutsuPractitioner
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IAlwaysWantedToSayThat
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IAmAMonster
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IAmBecomingSong
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IAmBigBoned
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IAmGreatSong
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IAmLegion
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IAmNotAGun
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IAmNotHim
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IAmNotLeftHanded
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IAmNotLeonardNimoy
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IAmNotMyFather
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IAmNotPretty
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IAmNotShazam
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IAmNotSpock
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IAmNotWeasel
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IAmNotYourFather
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IAmOneOfThoseToo
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IAmSong
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IAmSpartacus
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IAmTheBand
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IAmTheNoun
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IAmVeryBritish
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IAmWhatIAm
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IAmWho
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IAmXSonOfY
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IAmYourOpponent
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IApprovedThisMessage
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IAteWhat
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IBangedYourMom
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IBelieveICanFly
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IBelieveThatYouBelieveIt
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IBrokeANail
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ICallHimMisterHappy
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ICallItVera
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ICanChangeMyBeloved
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ICanExplain
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ICanLiveWithThat
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ICannotSelfTerminate
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ICanRuleAlone
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ICanSeeMyHouseFromHere
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ICanSeeYou
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ICanStillFight
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ICantBelieveAGuyLikeYouWouldNoticeMe
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ICantBelieveImSayingThis
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ICantBelieveItsNotHeroin
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ICantDance
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ICantDoThisByMyself
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ICantFeelMyLegs
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ICantHearYou
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ICantLookGesture
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ICantReachIt
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ICantSeeMyself
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ICantSenseTheirPresence
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IcarusAllusion
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IceBreaker
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IceCreamKoan
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IceCrystals
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IceMagicIsWater
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IcePalace
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IChooseToStay
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IComeInPeace
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ICommaNoun
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IconicAttributeAdoptionMoment
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IconicCharacterForgottenTitle
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IconicItem
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IconicOutfit
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IconicSequelCharacter
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IconicSequelOutfit
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IconicSequelSong
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IconicSongRequest
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IconicStarterEquipment
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IconOfRebellion
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IControlMyMinionsThrough
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ICouldaBeenAContender
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IcyBlueEyes
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdeaBulb
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdeaDing
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdealHero
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdealIllnessImmunity
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdealistVsPragmatist
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdealizedSex
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdenticalGrandson
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdenticalHairstylesGag
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdenticallyNamedGroup
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdenticallyPoweredTeam
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdenticalPanelGag
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdenticalStranger
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdenticalTwinIDTag
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdenticalTwinMistake
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdentificationByDentalRecords
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdentifyingTheBody
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdentityAbsorption
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdentityAmnesia
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdentityBreakdown
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdentityCoding
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdentityConcealmentDisposal
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdentityDenial
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdentityImpersonator
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IDidntMeanToKillHim
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IDidntMeanToTurnYouOn
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IDidntTellYouBecauseYoudBeUnhappy
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IDidWhatIHadToDo
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IDieFree
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdiosyncraticAlbumTheming
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdiosyncraticComboLevels
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdiosyncraticCoverArt
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdiosyncraticCulturalGesture
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdiosyncraticDifficultyLevels
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdiosyncraticEpisodeNaming
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdiosyncraticMechaStorage
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdiosyncraticMenuLabels
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdiosyncraticRatingsScale
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdiosyncraticShipNaming
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdiosyncraticWipes
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/Idiosyncrazy
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdiotBall
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdiotCrows
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdiotHair
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdiotHero
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdiotHoudini
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdioticPartnerConfession
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdiotPlot
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdiotSavant
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdiotsCannotCatchColds
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdleAnimation
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdlenessIndex
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdleRich
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdolGenre
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdolSinger
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IDoNotDrinkWine
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IDoNotLikeGreenEggsAndHam
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IDoNotOwn
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IDoNotSpeakNonverbal
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IDontKnowMortalKombat
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IDontLikeTheSoundOfThatPlace
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IDontLikeYouAndYouDontLikeMe
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IDontPayYouToThink
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IDontThinkThatsSuchAGoodIdea
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IDontWantToRuinOurFriendship
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdTellYouButThenIdHaveToKillYou
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IdyllicEnglishVillage
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IFeelGuiltyYouTakeIt
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IFellForHours
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IfICanOnlyMove
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IfICantHaveYou
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IfIDoNotReturn
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IFightForTheStrongestSide
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IfIHadANickel
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IfItBleedsItLeads
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IfItSwimsItFlies
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IfItsYouItsOkay
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IfItTastesBadItMustBeGoodForYou
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IfItWasFunnyTheFirstTime
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IfIWantedXIWouldY
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IfIWantedYouDead
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IfIWereARichMan
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IfJesusThenAliens
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IfMyCalculationsAreCorrect
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IfOnlyYouKnew
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IFoughtTheLawAndTheLawWon
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IFoundYouLikeThis
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IfWeGetThroughThis
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IfWeSurviveThis
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IfYouCallBeforeMidnightTonight
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IfYouCanReadThis
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IfYouDieICallYourStuff
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IfYouEverDoAnythingToHurtHer
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IfYouKillHimYouWillBeJustLikeHim
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IfYoureSoEvilEatThisKitten
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IfYouTauntHimYouWillBeJustLikeHim
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IfYouThoughtThatWasBad
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IfYouWontIWill
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IGaveMyWord
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IgnoranceIsBliss
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IgnorantAboutFire
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IgnorantMinion
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IgnorantOfTheCall
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IgnorantOfTheirOwnIgnorance
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IgnoredAesop
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IgnoredConfession
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IgnoredEnamoredUnderling
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IgnoredEnemy
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IgnoredEpiphany
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IgnoredExpert
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IgnoredRaisedHand
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IgnoredVitalNewsReports
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IgnoreTheDisability
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IgnoreTheFanservice
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IgnoringBySinging
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IgnoringTheDoctor
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IGotARock
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IGotBigger
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IGotYouADrawer
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IGotYouCovered
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IHatePastMe
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IHateSong
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IHateYouVampireDad
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IHaveAFamily
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IHaveBoobsYouMustObey
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IHaveBrothers
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IHaveJustOneThingToSay
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IHaveManyNames
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IHaveMyWays
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IHaveNoIdeaWhatImDoing
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IHaveNoSon
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IHaveNothingToSayToThat
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IHaveThisFriend
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IHaveYouNowMyPretty
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IHaveYourWife
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IHeardThat
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IHitYouYouHitTheGround
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IJustKnew
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IJustLikeSayingTheWord
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IJustShotMarvinInTheFace
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IJustWantToBeBadass
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IJustWantToBeBeautiful
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IJustWantToBeFree
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IJustWantToBeLoved
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IJustWantToBeNormal
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IJustWantToBeSpecial
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IJustWantToBeYou
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IJustWantToHaveFriends
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IJustWriteTheThing
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IKEAErotica
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IKEAWeaponry
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IKissYourFoot
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IKissYourHand
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IKnewIt
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IKnewThereWasSomethingAboutYou
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IKnowKarate
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IKnowKungFaux
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IKnowMaddenKombat
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IKnowMortalKombat
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IKnowWhatWeCanDoCut
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IKnowWhatYouFear
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IKnowYouKnowIKnow
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IKnowYoureInThereSomewhereFight
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IKnowYoureWatchingMe
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IKnowYourTrueName
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ILetGwenStacyDie
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ILetYouWin
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ILied
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ILikeMyXLikeILikeMyY
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ILikeThoseOdds
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IllBeInMyBunk
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IllBeYourBestFriend
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IllegalGamblingDen
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IllegalGuardian
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IllegalReligion
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IllFatedFlowerbed
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IllKillYou
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IllnessBlanket
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IllNeverTellYouWhatImTellingYou
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IllogicalSafe
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IllPretendIDidntHearThat
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IllTakeThatAsACompliment
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IllTakeTwoBeersToo
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IllTellYouWhenIveHadEnough
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IllTimedInfirmity
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IllTimedSneeze
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ILoveTheDead
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ILoveTheExties
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ILoveTheSmellOfXInTheMorning
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ILoveYouBecauseICantControlYou
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ILoveYouVampireSon
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/IMadeCopies
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ImADoctorNotAPlaceholder
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/Imageboards
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ImageBooru
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ImageMacro
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ImageSong
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ImaginaryEnemy
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ImaginaryFriend
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ImaginaryLoveTriangle
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ImaginationBasedSuperpower
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ImaginationDestroyer
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ImaginedInnuendo
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ImagineSpot
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ImagineSpotting
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ImagineTheAudienceNaked
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ImAHumanitarian
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/ImAManICantHelpIt
# ...
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NerfArm
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NervesOfSteel
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NervousTics
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NervousWreck
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NestedMouths
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NestedOwnership
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NestedStory
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NestedStoryReveal
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NetGun
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/Netorare
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NetworkDeath
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NetworkDecay
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NetworkFinale
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NetworkRedHeadedStepchild
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NetworkSideswipe
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NetworkSignOff
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NetworkToTheRescue
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeuralImplanting
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeurodiversityIsSupernatural
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeuroVault
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeutralEvil
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeutralFemale
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeutralGood
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeutralInNameOnly
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeutralityBacklash
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeutralitySue
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeutralNoLonger
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeutralsCrittersAndCreeps
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeutronBomb
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverAcceptedInHisHometown
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverARunaway
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverASelfMadeWoman
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverBareheaded
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverBeAHero
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverBeHurtAgain
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverBringAFriendToAnAudition
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverBringAGunToAKnifeFight
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverBringAKnifeToAFistFight
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverBringAKnifeToAGunFight
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverendingTerror
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverFilledOutOfficialPaperwork
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverForgottenSkill
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverFoundTheBody
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverGetsDrunk
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverGetsFat
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverGivenAName
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverGiveTheCaptainAStraightAnswer
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverGoingBackToPrison
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverGotToSayGoodbye
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverGrewUp
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverHadABirthdayParty
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverHadToys
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverHeardThatOneBefore
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverHurtAnInnocent
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverLand
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverLearnedToRead
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverLearnedToTalk
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverLendToAFriend
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverLiveItDown
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverMessWithGranny
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverMyFault
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverNeedsSharpening
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverOneMurder
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverRecycleABuilding
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverRecycleYourSchemes
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverSayDie
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverSayGoodbye
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverSayThatAgain
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverSentAnyLetters
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverSleepAgain
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverSmileAtACrocodile
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverSpeakIllOfTheDead
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverSplitTheParty
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverSuicide
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverTellMeTheOdds
# Request failed: 403 Client Error: Forbidden for url: https://tvtropes.org/pmwiki/pmwiki.php/Main/NeverTheObviousSuspect
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-858a728c70f8> in <cell line: 1>()
# ----> 1 df_copy[['trope_description', 'related_link_names','related_links']] = df_copy['trope_link'].apply(parsing_trope_page).apply(pd.Series)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4762             args=args,
#    4763             kwargs=kwargs,
# -> 4764         ).apply()
#    4765
#    4766     def _reindex_indexer(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1207
#    1208         # self.func is Callable
# -> 1209         return self.apply_standard()
#    1210
#    1211     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1287         #  Categorical (GH51645).
#    1288         action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1289         mapped = obj._map_values(
#    1290             mapper=curried, na_action=action, convert=self.convert_dtype
#    1291         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/base.py in _map_values(self, mapper, na_action, convert)
#     919             return arr.map(mapper, na_action=na_action)
#     920
# --> 921         return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#     922
#     923     @final
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py in map_array(arr, mapper, na_action, convert)
#    1812     values = arr.astype(object, copy=False)
#    1813     if na_action is None:
# -> 1814         return lib.map_infer(values, mapper, convert=convert)
#    1815     else:
#    1816         return lib.map_infer_mask(
#
# lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-5-39beb16c7b89> in parsing_trope_page(url)
#       7
#       8     try:
# ----> 9         response = requests.get(url)
#      10         response.raise_for_status()  # Raise an HTTPError for bad responses
#      11
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     723             # Redirect resolving generator.
#     724             gen = self.resolve_redirects(r, request, **kwargs)
# --> 725             history = [resp for resp in gen]
#     726         else:
#     727             history = []
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in <listcomp>(.0)
#     723             # Redirect resolving generator.
#     724             gen = self.resolve_redirects(r, request, **kwargs)
# --> 725             history = [resp for resp in gen]
#     726         else:
#     727             history = []
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     264             else:
#     265
# --> 266                 resp = self.send(
#     267                     req,
#     268                     stream=stream,
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     484
#     485         try:
# --> 486             resp = conn.urlopen(
#     487                 method=request.method,
#     488                 url=url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789
#     790             # Make the request on the HTTPConnection object
# --> 791             response = self._make_request(
#     792                 conn,
#     793                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535         # Receive the response from the server
#     536         try:
# --> 537             response = conn.getresponse()
#     538         except (BaseSSLError, OSError) as e:
#     539             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in getresponse(self)
#     459
#     460         # Get the response from http.client.HTTPConnection
# --> 461         httplib_response = super().getresponse()
#     462
#     463         try:
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1373         try:
#    1374             try:
# -> 1375                 response.begin()
#    1376             except ConnectionError:
#    1377                 self.close()
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     316         # read until we get a non-100 response
#     317         while True:
# --> 318             version, status, reason = self._read_status()
#     319             if status != CONTINUE:
#     320                 break
#
# /usr/lib/python3.10/http/client.py in _read_status(self)
#     277
#     278     def _read_status(self):
# --> 279         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280         if len(line) > _MAXLINE:
#     281             raise LineTooLong("status line")
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# /usr/lib/python3.10/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1301                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1302                   self.__class__)
# -> 1303             return self.read(nbytes, buffer)
#    1304         else:
#    1305             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.10/ssl.py in read(self, len, buffer)
#    1157         try:
#    1158             if buffer is not None:
# -> 1159                 return self._sslobj.read(len, buffer)
#    1160             else:
#    1161                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df_copy.head()

# %%
df_copy.info()

# %% [markdown]
# # Widespread Downloading

# %%
df = pd.read_csv('all_trope_names_links.csv')

# %%
output_folder = '/content/drive/MyDrive/04 Class Directed Reading/Trope_Comic_Research/data_raw/Webpages'

# %%
for index, row in df.iterrows():
    try:
        name = row['trope_name']
        url = row['trope_link']

        # Define the file path
        file_path = os.path.join(output_folder, f"{name}.html")

        # Check if the file already exists
        if os.path.exists(file_path):
            print(f"File already exists for {name}, skipping download.")
            continue

        # Request the HTML content
        response = requests.get(url)
        response.raise_for_status()  # Check for HTTP errors

        # Save the content to a file named after the trope_name
        with open(file_path, 'w', encoding='utf-8') as file:
            file.write(response.text)

        print(f"Successfully downloaded: {name}")

    except requests.exceptions.RequestException as e:
        print(f"Failed to download {name} at row {index}: {e}")
        break  # Stop the loop if there is an error

print("Download process completed.")
# Out:
# File already exists for Aardvark Trunks, skipping download.
# File already exists for Abandoned Area, skipping download.
# File already exists for Abandoned Camp Ruins, skipping download.
# File already exists for Abandoned Catchphrase, skipping download.
# File already exists for Abandoned Hospital, skipping download.
# File already exists for Abandoned Hospital Awakening, skipping download.
# File already exists for Abandoned Info Page, skipping download.
# File already exists for Abandoned Laboratory, skipping download.
# File already exists for Abandoned Mascot, skipping download.
# File already exists for Abandoned Mine, skipping download.
# Successfully downloaded: Abandoned Pet In A Box
# Successfully downloaded: Abandoned Playground
# Successfully downloaded: Abandoned War Child
# Successfully downloaded: Abandoned Warehouse
# Successfully downloaded: Abandonment Induced Animosity
# Successfully downloaded: Abandon Ship
# Successfully downloaded: Abandon Shipping
# Successfully downloaded: Abandon The Disabled
# Successfully downloaded: Abandonware
# Successfully downloaded: Abbey Road Crossing
# Successfully downloaded: Abdicate The Throne
# Successfully downloaded: Abduction Is Love
# Successfully downloaded: A Beast In Name And Nature
# Successfully downloaded: Abhorrent Admirer
# Successfully downloaded: Abilene Paradox
# Successfully downloaded: Ability Depletion Penalty
# Successfully downloaded: Ability Mixing
# Successfully downloaded: Ability Over Appearance
# Successfully downloaded: Ability Required To Proceed
# Successfully downloaded: A Birthday Not A Break
# Successfully downloaded: Abled In The Adaptation
# Successfully downloaded: A Bloody Mess
# Successfully downloaded: AB Negative
# Successfully downloaded: Abnormal Allergy
# Successfully downloaded: Abnormal Ammo
# Successfully downloaded: Abnormal Dental Growth
# Successfully downloaded: Abnormal Limb Rotation Range
# Successfully downloaded: Abnormal Plushies
# Successfully downloaded: Abominable Auditorium
# Successfully downloaded: Abomination Accusation Attack
# Successfully downloaded: Aborted Arc
# Successfully downloaded: Aborted Declaration Of Love
# Successfully downloaded: Abortion Fallout Drama
# Successfully downloaded: About The Author
# Successfully downloaded: Above Good And Evil
# Successfully downloaded: Above The Gods
# Successfully downloaded: Above The Influence
# Successfully downloaded: A Boy A Girl And A Baby Family
# Successfully downloaded: A Boy And His X
# Successfully downloaded: Abridged Arena Array
# Successfully downloaded: Abridged For Children
# Successfully downloaded: Absence Makes The Heart Go Yonder
# Successfully downloaded: Absence Of Evidence
# Successfully downloaded: Absent Aliens
# Successfully downloaded: Absent Animal Companion
# Successfully downloaded: Absentee Club Member
# Successfully downloaded: Absent Minded Professor
# Successfully downloaded: Absolute Comparative
# Successfully downloaded: Absolute Xenophobe
# Successfully downloaded: Abstract Apotheosis
# Successfully downloaded: Abstract Eater
# Successfully downloaded: Abstract Scale
# Successfully downloaded: Abstract Strategy Game
# Successfully downloaded: Absurd Altitude
# Successfully downloaded: Absurd Brand Name
# Successfully downloaded: Absurd Cutting Power
# Successfully downloaded: Absurdism
# Successfully downloaded: Absurdly Bright Light
# Successfully downloaded: Absurdly Cool City
# Successfully downloaded: Absurdly Dedicated Worker
# Successfully downloaded: Absurdly Divided School
# Successfully downloaded: Absurdly Elderly Father
# Successfully downloaded: Absurdly Elderly Mother
# Successfully downloaded: Absurdly Exclusive Recruiting Standards
# Successfully downloaded: Absurdly High Cap
# Successfully downloaded: Absurdly High Level Cap
# Successfully downloaded: Absurdly High Stakes Game
# Successfully downloaded: Absurdly Huge Population
# Successfully downloaded: Absurdly Ineffective Barricade
# Successfully downloaded: Absurdly Long Limousine
# Successfully downloaded: Absurdly Long Stairway
# Successfully downloaded: Absurdly Long Wait
# Successfully downloaded: Absurdly Low Level Cap
# Successfully downloaded: Absurdly Powerful School Jurisdiction
# Successfully downloaded: Absurdly Powerful Student Council
# Successfully downloaded: Absurdly Sharp Blade
# Successfully downloaded: Absurdly Sharp Claws
# Successfully downloaded: Absurdly Short Level
# Successfully downloaded: Absurdly Short Production Time
# Successfully downloaded: Absurdly Spacious Sewer
# Successfully downloaded: Absurdly Youthful Mother
# Successfully downloaded: Absurd Phobia
# Successfully downloaded: Ab Urbe Condita
# Successfully downloaded: Abuse Discretion Shot
# Successfully downloaded: Abuse Mistake
# Successfully downloaded: Abuse Of Return Policy
# Successfully downloaded: Abusive Advertising
# Successfully downloaded: Abusive Alien Parents
# Successfully downloaded: Abusive Offspring
# Successfully downloaded: Abusive Parents
# Successfully downloaded: Abusive Precursors
# Successfully downloaded: Abusive Workplace
# Successfully downloaded: Academia Elitism
# Successfully downloaded: Academic Alpha Bitch
# Successfully downloaded: Academic Athlete
# Successfully downloaded: Academy Of Adventure
# Successfully downloaded: Academy Of Evil
# Successfully downloaded: A Cappella
# Successfully downloaded: A Cat In A Gang Of Dogs
# Successfully downloaded: Accent Adaptation
# Successfully downloaded: Accent Depundent
# Successfully downloaded: Accent Interest
# Successfully downloaded: Accent Relapse
# Successfully downloaded: Accents Arent Hereditary
# Successfully downloaded: Accent Slip Up
# Successfully downloaded: Accentuate The Negative
# Successfully downloaded: Accent Upon The Wrong Syllable
# Successfully downloaded: Acceptable Breaks From Canon
# Successfully downloaded: Accessory Wearing Cartoon Animal
# Successfully downloaded: Accidental Adultery
# Successfully downloaded: Accidental Aesop
# Successfully downloaded: Accidental Aiming Skills
# Successfully downloaded: Accidental Art
# Successfully downloaded: Accidental Astronaut
# Successfully downloaded: Accidental Athlete
# Successfully downloaded: Accidental Bargaining Skills
# Successfully downloaded: Accidental Bid
# Successfully downloaded: Accidental Celebrity
# Successfully downloaded: Accidental Child Killer Backstory
# Successfully downloaded: Accidental Dance Craze
# Successfully downloaded: Accidental Declaration Of Love
# Successfully downloaded: Accidental Discovery
# Successfully downloaded: Accidental Downer Ending
# Successfully downloaded: Accidental Good Outcome
# Successfully downloaded: Accidental Hand Hold
# Successfully downloaded: Accidental Hero
# Successfully downloaded: Accidental Hug
# Successfully downloaded: Accidental Incantation
# Successfully downloaded: Accidental Injury Guilt
# Successfully downloaded: Accidental Innuendo
# Successfully downloaded: Accidental Kidnapping
# Successfully downloaded: Accidental Kiss
# Successfully downloaded: Accidentally Broke The Mac Guffin
# Successfully downloaded: Accidentally Correct Writing
# Successfully downloaded: Accidentally Correct Zoology
# Successfully downloaded: Accidentally Real Fake Address
# Successfully downloaded: Accidental Marriage
# Successfully downloaded: Accidental Misnaming
# Successfully downloaded: Accidental Murder
# Successfully downloaded: Accidental Nightmare Fuel
# Successfully downloaded: Accidental Passenger
# Successfully downloaded: Accidental Pervert
# Successfully downloaded: Accidental Pornomancer
# Successfully downloaded: Accidental Proposal
# Successfully downloaded: Accidental Public Confession
# Successfully downloaded: Accidental Pun
# Successfully downloaded: Accidental Rhyme
# Successfully downloaded: Accidental Suicide
# Successfully downloaded: Accidental Theft
# Successfully downloaded: Accidental Tickle Torture
# Successfully downloaded: Accidental Time Travel
# Successfully downloaded: Accidental Truth
# Successfully downloaded: Accidental Unfortunate Gesture
# Successfully downloaded: Accidental Ventriloquism
# Successfully downloaded: Accident Not Murder
# Successfully downloaded: Acclaimed Flop
# Successfully downloaded: Accomplice By Inaction
# Successfully downloaded: Accordion Man
# Successfully downloaded: Accordion To Most Sailors
# Successfully downloaded: Accusation Fic
# Successfully downloaded: Accuser Of The Brethren
# Successfully downloaded: Accuse The Witness
# Successfully downloaded: Ace Custom
# Successfully downloaded: Ace Of Spades
# Successfully downloaded: Ace Pilot
# Successfully downloaded: A Chat With Satan
# Successfully downloaded: Achey Scars
# Successfully downloaded: Achievement Mockery
# Successfully downloaded: Achievements In Ignorance
# Successfully downloaded: Achievement System
# Successfully downloaded: Achievement Test Of Destiny
# Successfully downloaded: A Child Shall Lead Them
# Successfully downloaded: Achilles Heel
# Successfully downloaded: Achilles In His Tent
# Successfully downloaded: Achilles Power Cord
# Successfully downloaded: Acid Attack
# Successfully downloaded: Acid Pool
# Successfully downloaded: Acid Reflux Nightmare
# Successfully downloaded: Acid Trip Dimension
# Successfully downloaded: Acme Products
# Successfully downloaded: A Commander Is You
# Successfully downloaded: Acoustic License
# Successfully downloaded: Acquaintance Denial
# Successfully downloaded: Acquainted In Real Life
# Successfully downloaded: Acquainted With Emergency Services
# Successfully downloaded: Acquired Error At The Printer
# Successfully downloaded: Acquired Poison Immunity
# Successfully downloaded: Acquired Situational Narcissism
# Successfully downloaded: Acquitted Too Late
# Successfully downloaded: A Crack In The Ice
# Successfully downloaded: Acrofatic
# Successfully downloaded: Acronym And Abbreviation Overload
# Successfully downloaded: Acronym Confusion
# Successfully downloaded: Acronyms Are Easy As Aybeecee
# Successfully downloaded: Acrophobic Bird
# Successfully downloaded: Act Break
# Successfully downloaded: Acting For Two
# Successfully downloaded: Acting In The Dark
# Successfully downloaded: Acting Out A Daydream
# Successfully downloaded: Acting Unnatural
# Successfully downloaded: Acting Your Intellectual Age
# Successfully downloaded: Action Bar
# Successfully downloaded: Action Based Mission
# Successfully downloaded: Action Bomb
# Successfully downloaded: Action Commands
# Successfully downloaded: Action Dad
# Successfully downloaded: Action Dress Rip
# Successfully downloaded: Action Duo
# Successfully downloaded: Action Fashionista
# Successfully downloaded: Action Figure File Card
# Successfully downloaded: Action Figure Justification
# Successfully downloaded: Action Figure Speech
# Successfully downloaded: Action Film Quiet Drama Scene
# Successfully downloaded: Action Genre
# Successfully downloaded: Action Genre Hero Guy
# Successfully downloaded: Action Girl
# Successfully downloaded: Action Girlfriend
# Successfully downloaded: Action Hero
# Successfully downloaded: Action Hero Babysitter
# Successfully downloaded: Action Hogging Opening
# Successfully downloaded: Action Horror
# Successfully downloaded: Action Initiative
# Successfully downloaded: Action Insurance Gag
# Successfully downloaded: Actionized Adaptation
# Successfully downloaded: Actionized Sequel
# Successfully downloaded: Action Mom
# Successfully downloaded: Action Pet
# Successfully downloaded: Action Politician
# Successfully downloaded: Action Prologue
# Successfully downloaded: Action Survivor
# Successfully downloaded: Activation Sequence
# Successfully downloaded: Activist Fundamentalist Antics
# Successfully downloaded: Act Of True Love
# Successfully downloaded: Actor Allusion
# Successfully downloaded: Actor Existence Limbo
# Successfully downloaded: Actor Inspired Element
# Successfully downloaded: Actor Inspired Heroism
# Successfully downloaded: Actor Is The Title Character
# Successfully downloaded: Actor Leaves Character Dies
# Successfully downloaded: Actor Muso Show
# Successfully downloaded: Actor Role Confusion
# Successfully downloaded: Actor Shared Background
# Successfully downloaded: Actor Shipping
# Successfully downloaded: Actor Swap
# Successfully downloaded: Actually A Doombot
# Successfully downloaded: Actually A Good Idea
# Successfully downloaded: Actually Four Mooks
# Successfully downloaded: Actually I Am Him
# Successfully downloaded: Actually Not A Vampire
# Successfully downloaded: Actually Pretty Funny
# Successfully downloaded: Actually Quite Catchy
# Successfully downloaded: Actually Thats My Assistant
# Successfully downloaded: Actual Pacifist
# Successfully downloaded: Actual Play
# Successfully downloaded: A Cup Angst
# Successfully downloaded: Adam And Eve Plot
# Successfully downloaded: Adam And Or Eve
# Successfully downloaded: Adam Smith Hates Your Guts
# Successfully downloaded: Adam Westing
# Successfully downloaded: Adaptational Abomination
# Successfully downloaded: Adaptational Achilles Heel
# Successfully downloaded: Adaptational Alternate Ending
# Successfully downloaded: Adaptational Angst Downgrade
# Successfully downloaded: Adaptational Angst Upgrade
# Successfully downloaded: Adaptational Attractiveness
# Successfully downloaded: Adaptational Backstory Change
# Successfully downloaded: Adaptational Badass
# Successfully downloaded: Adaptational Comic Relief
# Successfully downloaded: Adaptational Consent
# Successfully downloaded: Adaptational Consistency
# Successfully downloaded: Adaptational Context Change
# Successfully downloaded: Adaptational Curves
# Successfully downloaded: Adaptational Diversity
# Successfully downloaded: Adaptational Dumbass
# Successfully downloaded: Adaptational Early Appearance
# Successfully downloaded: Adaptational Explanation
# Successfully downloaded: Adaptational Friendship
# Successfully downloaded: Adaptational Gender Identity
# Successfully downloaded: Adaptational Goal Change
# Successfully downloaded: Adaptational Hairstyle Change
# Successfully downloaded: Adaptational Heroism
# Successfully downloaded: Adaptational Intelligence
# Successfully downloaded: Adaptational Jerkass
# Successfully downloaded: Adaptational Job Change
# Successfully downloaded: Adaptational Karma
# Successfully downloaded: Adaptational Late Appearance
# Successfully downloaded: Adaptational Location Change
# Successfully downloaded: Adaptational Modesty
# Successfully downloaded: Adaptational Mundanity
# Successfully downloaded: Adaptational Nationality
# Successfully downloaded: Adaptational Nice Guy
# Successfully downloaded: Adaptational Nonsapience
# Successfully downloaded: Adaptational Protagonist
# Successfully downloaded: Adaptational Romance Downgrade
# Successfully downloaded: Adaptational Secrecy Downgrade
# Successfully downloaded: Adaptational Self Defense
# Successfully downloaded: Adaptational Seriousness
# Successfully downloaded: Adaptational Sexuality
# Successfully downloaded: Adaptational Skill
# Successfully downloaded: Adaptational Skimpiness
# Successfully downloaded: Adaptational Slimness
# Successfully downloaded: Adaptational Superpower Change
# Successfully downloaded: Adaptational Sympathy
# Successfully downloaded: Adaptational Timespan Change
# Successfully downloaded: Adaptational Ugliness
# Successfully downloaded: Adaptational Upbringing Change
# Successfully downloaded: Adaptational Villainy
# Successfully downloaded: Adaptational Wealth
# Successfully downloaded: Adaptational Weapon Swap
# Successfully downloaded: Adaptational Wimp
# Successfully downloaded: Adaptation Amalgamation
# Successfully downloaded: Adaptation Decay
# Successfully downloaded: Adaptation Deviation
# Successfully downloaded: Adaptation Displacement
# Successfully downloaded: Adaptation Distillation
# Successfully downloaded: Adaptation Drift
# Successfully downloaded: Adaptation Dye Job
# Successfully downloaded: Adaptation Expansion
# Successfully downloaded: Adaptation Explanation Extrication
# Successfully downloaded: Adaptation First
# Successfully downloaded: Adaptation Induced Plot Hole
# Successfully downloaded: Adaptation Inspiration
# Successfully downloaded: Adaptation Name Change
# Successfully downloaded: Adaptation Origin Connection
# Successfully downloaded: Adaptation Overdosed
# Successfully downloaded: Adaptation Personality Change
# Successfully downloaded: Adaptation Relationship Overhaul
# Successfully downloaded: Adaptation Sequence
# Successfully downloaded: Adaptation Species Change
# Successfully downloaded: Adaptation Title Change
# Successfully downloaded: Adapted Out
# Successfully downloaded: Adaptive Ability
# Successfully downloaded: Adaptive Armor
# Successfully downloaded: A Darker Me
# Successfully downloaded: A Day In Her Apron
# Successfully downloaded: A Day In The Limelight
# Successfully downloaded: Ad Break Double Take
# Successfully downloaded: Ad Bumpers
# Successfully downloaded: Added Alliterative Appeal
# Successfully downloaded: Addiction Displacement
# Successfully downloaded: Addiction Powered
# Successfully downloaded: Addiction Song
# Successfully downloaded: Addictive Foreign Soap Opera
# Successfully downloaded: Addictive Magic
# Successfully downloaded: Ad Dissonance
# Successfully downloaded: Addled Addict
# Successfully downloaded: Addressing The Player
# Successfully downloaded: A Deadly Affair
# Successfully downloaded: A Death In The Limelight
# Successfully downloaded: A Degree In Useless
# Successfully downloaded: Ad Hominem
# Successfully downloaded: A Dick In Name
# Successfully downloaded: Adipose Rex
# Successfully downloaded: Adjacent To This Complete Breakfast
# Successfully downloaded: Adjective Animal Alehouse
# Successfully downloaded: Adjective Noun Fred
# Successfully downloaded: Adjustable Censorship
# Successfully downloaded: Adminisphere
# Successfully downloaded: Admiring The Abomination
# Successfully downloaded: Admiring The Poster
# Successfully downloaded: A Dog Ate My Homework
# Successfully downloaded: A Dog Named Cat
# Successfully downloaded: A Dog Named Dog
# Successfully downloaded: A Dog Named Perro
# Successfully downloaded: Adolf Hitlarious
# Successfully downloaded: A Doormat To His Men
# Successfully downloaded: Adopt A Servant
# Successfully downloaded: Adopted Into Royalty
# Successfully downloaded: Adopted To The House
# Successfully downloaded: Adopting The Abused
# Successfully downloaded: Adopting The Gender Binary
# Successfully downloaded: Adoption Angst
# Successfully downloaded: Adoption Conflict
# Successfully downloaded: Adoption Diss
# Successfully downloaded: Adoption Induced Pregnancy
# Successfully downloaded: Adoption Is Not An Option
# Successfully downloaded: Adoptive Name Change
# Successfully downloaded: Adoptive Peer Parent
# Successfully downloaded: Adopt The Dog
# Successfully downloaded: Adopt The Food
# Successfully downloaded: Adorable Abomination
# Successfully downloaded: Adorable Evil Minions
# Successfully downloaded: Adorable Fluffy Tail
# Successfully downloaded: Adorably Precocious Child
# Successfully downloaded: Adored By The Network
# Successfully downloaded: Adoring The Pests
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-a4b770966cdb> in <cell line: 1>()
#      13
#      14         # Request the HTML content
# ---> 15         response = requests.get(url)
#      16         response.raise_for_status()  # Check for HTTP errors
#      17
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     723             # Redirect resolving generator.
#     724             gen = self.resolve_redirects(r, request, **kwargs)
# --> 725             history = [resp for resp in gen]
#     726         else:
#     727             history = []
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in <listcomp>(.0)
#     723             # Redirect resolving generator.
#     724             gen = self.resolve_redirects(r, request, **kwargs)
# --> 725             history = [resp for resp in gen]
#     726         else:
#     727             history = []
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     264             else:
#     265
# --> 266                 resp = self.send(
#     267                     req,
#     268                     stream=stream,
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     484
#     485         try:
# --> 486             resp = conn.urlopen(
#     487                 method=request.method,
#     488                 url=url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789
#     790             # Make the request on the HTTPConnection object
# --> 791             response = self._make_request(
#     792                 conn,
#     793                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     466             # Trigger any extra validation we need to do.
#     467             try:
# --> 468                 self._validate_conn(conn)
#     469             except (SocketTimeout, BaseSSLError) as e:
#     470                 self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1095         # Force connect early to allow us to validate the connection.
#    1096         if conn.is_closed:
# -> 1097             conn.connect()
#    1098
#    1099         if not conn.is_verified:
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in connect(self)
#     640             )
#     641
# --> 642         sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     643             sock=sock,
#     644             cert_reqs=self.cert_reqs,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     781             server_hostname = normalized
#     782
# --> 783     ssl_sock = ssl_wrap_socket(
#     784         sock=sock,
#     785         keyfile=key_file,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     444     if ca_certs or ca_cert_dir or ca_cert_data:
#     445         try:
# --> 446             context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     447         except OSError as e:
#     448             raise SSLError(e) from e
#
# KeyboardInterrupt:
